# %%
import torch
from sklearn.preprocessing import StandardScaler
import torch.utils.data as data_utils
import numpy as np


def create_inout_sequences_tra(data, tw, test_size):
    
    data = np.array(data)
    L = len(data)
    data = data[:(L//tw)*tw]
    scaler = StandardScaler()
    scaler = scaler.fit(data[:-tw*test_size])
    data = scaler.transform(data)
    
    x = []
    y = []
    
    for i in range(L//tw):
        i = i*tw
        train_seq = data[:,0:4][i:i+tw]
        train_label = data[:,4][i:i+tw]
        x.append(train_seq)
        y.append(train_label)

    y_train = torch.tensor(y[:-test_size])
    y_test = torch.tensor(y[-test_size:])
    x_train = torch.tensor(x[:-test_size])
    x_test = torch.tensor(x[-test_size:])  
    
    train_dataset = data_utils.TensorDataset(x_train, y_train)
    train_loader = data_utils.DataLoader(train_dataset, batch_size=len(train_dataset), shuffle=False)

    test_dataset = data_utils.TensorDataset(x_test, y_test)
    test_loader = data_utils.DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=False)
    
    return train_loader, test_loader, scaler

# %%
def create_inout_sequences_opt(data, tw, test_size):
    
    data = np.array(data)
    L = len(data)
    data = data[:(L//tw)*tw]
    scaler = StandardScaler()
    scaler = scaler.fit(data[:-tw*test_size])
    data = scaler.transform(data)
    
    x = []
    y = []
    
    for i in range(L//tw):
        i = i*tw
        train_seq = data[:,0][i:i+tw]
        train_label = data[:,1][i:i+tw]
        x.append(train_seq)
        y.append(train_label)

    y_train = torch.tensor(y[:-test_size])
    y_test = torch.tensor(y[-test_size:])
    x_train = torch.tensor(x[:-test_size])
    x_test = torch.tensor(x[-test_size:])  
    
    train_dataset = data_utils.TensorDataset(x_train, y_train)
    train_loader = data_utils.DataLoader(train_dataset, batch_size=len(train_dataset), shuffle=False)

    test_dataset = data_utils.TensorDataset(x_test, y_test)
    test_loader = data_utils.DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=False)
    
    return train_loader, test_loader, scaler

# %%
def create_inout_sequences_pm(data, tw, test_size):
    
    data = np.array(data)
    L = len(data)
    data = data[:(L//tw)*tw]
    scaler = StandardScaler()
    scaler = scaler.fit(data[:-tw*test_size])
    data = scaler.transform(data)
    
    x = []
    y = []
    
    for i in range(L//tw):
        i = i*tw
        train_seq = data[:,0:6][i:i+tw]
        train_label = data[:,6][i:i+tw]
        x.append(train_seq)
        y.append(train_label)

    y_train = torch.tensor(y[:-test_size])
    y_test = torch.tensor(y[-test_size:])
    x_train = torch.tensor(x[:-test_size])
    x_test = torch.tensor(x[-test_size:])  
    
    train_dataset = data_utils.TensorDataset(x_train, y_train)
    train_loader = data_utils.DataLoader(train_dataset, batch_size=len(train_dataset), shuffle=False)

    test_dataset = data_utils.TensorDataset(x_test, y_test)
    test_loader = data_utils.DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=False)
    
    return train_loader, test_loader, scaler

# %%
def create_inout_sequences_chick(data, tw, test_size):
    
    data = np.array(data)
    L = len(data)
    data = data[:(L//tw)*tw]
    scaler = StandardScaler()
    scaler = scaler.fit(data[:-tw*test_size])
    data = scaler.transform(data)
    
    x = []
    y = []
    
    for i in range(L//tw):
        i = i*tw
        train_seq = data[:,0:4][i:i+tw]
        train_label = data[:,4][i:i+tw]
        x.append(train_seq)
        y.append(train_label)
    
    y_train = torch.tensor(y[:-test_size])
    y_test = torch.tensor(y[-test_size:])
    x_train = torch.tensor(x[:-test_size])
    x_test = torch.tensor(x[-test_size:])  
    # print(x_train[0])
    # print(y_train[0])
    train_dataset = data_utils.TensorDataset(x_train, y_train)
    train_loader = data_utils.DataLoader(train_dataset, batch_size=len(train_dataset), shuffle=False)

    test_dataset = data_utils.TensorDataset(x_test, y_test)
    test_loader = data_utils.DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=False)
    
    return train_loader, test_loader, scaler

# %%
import torch
import torch.distributions as distribution

def init_network_weights(model):
    if type(model) == torch.nn.Linear:
        torch.nn.init.xavier_uniform_(model.weight)
        if model.bias is not None:
            model.bias.data.fill_(0.0)
            
def normal_distribution(mu, var):

    #var = torch.exp(0.5*logvar)
    normal = distribution.Normal(mu, var)
    return normal


def sample_from_normal(mu, var):
    normal = normal_distribution(mu, var)
    sample = normal.rsample()
    return sample

def loss_function(recon, data, Z_prior, Z_posterior, var = 1.0):

    normal = distribution.Normal(recon, var)
    log_likelihood = normal.log_prob(data).sum()

    
    prior = normal_distribution(Z_prior[0],Z_prior[1])
    posterior = normal_distribution(Z_posterior[0],Z_posterior[1])
    
    #priorh = normal_distribution(torch.zeros_like(h_mean_var[0]),torch.ones_like(h_mean_var[1]))
    #posteriorh = normal_distribution(h_mean_var[0],h_mean_var[1])
    
    KL = distribution.kl_divergence(posterior,prior).sum()
    #KL3 = distribution.kl_divergence(posteriorh,priorh).sum()

    return -log_likelihood + KL
    #return -log_likelihood

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jan 18 11:29:41 2021

@author: tonyz
"""

import torch.nn as nn


def one_layer(input_size,output_size,activation,layer_type=None):
    
    if activation == "relu":
        act = nn.ReLU(inplace=True)
    if activation == "tanh":
        act = nn.Tanh()
    if activation == "sigmoid":
        act = nn.Sigmoid()
    layer=[]
    if layer_type is None:
        layer.append(nn.Linear(input_size,output_size))
        layer.append(act)
    else:
        layer.append(nn.Linear(input_size,output_size))

        
    return nn.Sequential(*layer)


class MLP(nn.Module):

    def __init__(self, input_size, hidden_size, output_size, layers, activation='relu'):

        super().__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.layers = layers
        
        sequence = []
        for layer in range(self.layers-1):
            if layer == 0:
                sequence.append(one_layer(self.input_size,self.hidden_size,activation))
            elif layer == self.layers-2:
                sequence.append(one_layer(self.hidden_size,self.output_size,activation,"output"))
            else:
                sequence.append(one_layer(self.hidden_size,self.hidden_size,activation))
        
        self.mlp = nn.Sequential(*sequence)
        
    def forward(self, x):

        return self.mlp(x)

# %%
import torch
import torch.nn as nn
# from multi_layer_perceptron import MLP


class GRUCell(nn.Module):
    def __init__(self, input_size, hidden_size, bias=True):

        super().__init__()

        self.lin_x = torch.nn.Linear(input_size, hidden_size * 3, bias=bias)
        self.lin_r = torch.nn.Linear(hidden_size, hidden_size, bias=False)
        self.lin_z = torch.nn.Linear(hidden_size, hidden_size, bias=False)
        self.lin_g = torch.nn.Linear(hidden_size, hidden_size, bias=False)

    def forward(self, x, h):
        xr, xz, xg = torch.chunk(self.lin_x(x), 3, dim=-1)
        r = torch.sigmoid(xr + self.lin_r(h))
        z = torch.sigmoid(xz + self.lin_z(h))
        g = torch.tanh(xg + self.lin_g(r * h))

        h_new = z * h + (1-z) * g
        dh = (1-z) * (g-h)
        return h_new, dh
import torch.nn as nn

        
#         # weight values
#         values = values.permute(1,0,2) # [T,B,H] -> [B,T,H]
#         combo = torch.bmm(scores, values).squeeze(1) # [B,1,T]*[B,T,H] -> [B,H]

#         return (combo, scores)

class GRUVAE(nn.Module):

    def __init__(self, input_size, gru_hidden_size, inf_gru_hidden_size, output_size, Z_size, n_mlp, bias=True):
        super().__init__()

        # Attributes
        self.input_size = input_size #size of gru
        self.gru_hidden_size = gru_hidden_size #hidden size of gru-vae
        self.inf_gru_hidden_size = inf_gru_hidden_size #hidden size of gru for Z inference
        self.output_size = output_size
        self.Z_size = Z_size #size of auxillary random var Z
        self.n_mlp = n_mlp #number of mlp layers
        
        # Prior of Z
        self.Z_prior = MLP(self.gru_hidden_size, self.gru_hidden_size, self.Z_size*2, self.n_mlp)
        # Posterior of Z
        

        #self.gru_Z = nn.GRU(self.input_size, self.inf_gru_hidden_size, 1)
        self.gru_Z = nn.GRU(1, self.inf_gru_hidden_size, 1)
        self.Z_post = nn.Linear(self.inf_gru_hidden_size, self.Z_size * 2)
        
        # main gru model
        self.gru = GRUCell(self.Z_size+self.input_size, self.gru_hidden_size, bias=bias)
        
        # emission model
        #self.emission = MLP(self.gru_hidden_size,self.gru_hidden_size,self.output_size*2,self.n_mlp)
        self.emission = MLP(self.gru_hidden_size,self.gru_hidden_size,self.output_size,self.n_mlp)
        # map hidden state to option price
        self.map = nn.Linear(self.gru_hidden_size, self.output_size*2)
        # self.mha = MultiHeadAttention(gru_hidden_size,4)

        self.attension = nn.Linear(self.gru_hidden_size+Z_size,1)
        # self.adat = AdditiveAttention(self.gru_hidden_size,self.Z_size)
        self.tanh = nn.Tanh()
        self.softmax = nn.Softmax(dim=0)
    def Z_inference(self, gru_hidden_state):
        Z_mean_var = self.Z_post(gru_hidden_state)
        Z_mean_var = torch.chunk(Z_mean_var, 2, dim=-1)
        Z_std = torch.exp(0.5*Z_mean_var[1]) # convert logvar to std
        #Z_std = Z_mean_var[1]
        Z = sample_from_normal(Z_mean_var[0],Z_std)
        return Z, (Z_mean_var[0],Z_std)
    
    # returns next gru hidden state
    def run_GRU(self, x_prime, gru_hidden_state):

        gru_output,dh = self.gru(x_prime, gru_hidden_state)             
        return gru_output,dh

    def laten_att(self, encoder_output,hidden):
       
        h_attension = hidden.repeat(encoder_output.size(0),1,1)
        # print(h_attension.shape)
        # print(encoder_output.shape)
        attention = self.tanh(self.attension(torch.cat((h_attension,encoder_output),dim=2)))
        attention = self.softmax(attention)
        # print(attention)
        c = torch.bmm(attention.permute(1,2,0),encoder_output.permute(1,0,2)).permute(1,0,2)
        
        return c[0][0],attention
    
    def reconstruct(self, gru_hidden_state):

        reconstruction = self.emission(gru_hidden_state)
        return (reconstruction,reconstruction,0)
    

    def run_GRUVAE(self, gru_hidden_size, inf_gru_hidden_size,x, y, h=False):

        dhs = []
        Zs, Z_posteriors, Z_priors = [], [], [] 
        y = y.view(len(y),1,1)
        h_sequence = self.gru_Z(y.float())[0]
        # y = y.view(1,1,len(y))
        # # h_sequence = self.gru_Z(y.float())[0]
        # h_sequence = self.CNN(y.float())
        # print(h_sequence.shape)
        if h is not False:
            h=h
        else:
            h = torch.zeros(gru_hidden_size).to("cuda")
            Z_t = torch.zeros(self.Z_size).to("cuda").unsqueeze(0).unsqueeze(0)
            h_t = torch.zeros(self.gru_hidden_size).to("cuda").unsqueeze(0).unsqueeze(0)
            #h = h_sequence_reverse
            #h = torch.randn(gru_hidden_size)
        hidden_states = [h]
        # print(Z_t)
        for t in range(1,len(x)):
            #x_prime = torch.cat([h,x[t].view(-1).float()])
            Z_prior = self.Z_prior(h)   
            Z_prior = torch.chunk(Z_prior, 2, dim=-1)
            Z_std = torch.exp(0.5*Z_prior[1])
            #Z_std = abs(Z_prior[1])
            Z_priors.append((Z_prior[0],Z_std))
            
            Z, Z_posterior = self.Z_inference(h_sequence[t].view(inf_gru_hidden_size))
            Z_posteriors.append(Z_posterior)
            Zs.append(Z)
            Z_t = torch.cat((Z_t,Z.unsqueeze(0).unsqueeze(0)),0)
            att,draw = self.laten_att(Z_t[1:],h)
            # att,_ = self.adat(None,h.unsqueeze(0),Z_t[1:])
            x_prime = torch.cat([att,x[t].view(-1).float()])
            h_new,dh = self.run_GRU(x_prime,h)
            hidden_states.append(h_new)
            dhs.append(dh)
            h = h_new
        return Z_priors, Zs, Z_posteriors, hidden_states,dhs
      
    def forward(self, x, y, h=False):

        Z_priors, Zs, Z_posteriors, hidden_states,dhs = self.run_GRUVAE(self.gru_hidden_size,self.inf_gru_hidden_size,x,y,h)
        means = []
        samples = []
        for time in range(1,len(x)):
            mean,sample,std = self.reconstruct(hidden_states[time])
            means.append(mean)
            samples.append(sample)

        return means, samples, hidden_states, Z_priors, Zs, Z_posteriors, dhs, std
        

    
import warnings
warnings.filterwarnings("ignore")

# %%
import torch
# from functions import loss_function
import torch.nn as nn
import copy

class AutoEncoderTrainer:
    """AutoEncoder Training class."""
    def __init__(self, model, optimizer, train_loader, test_loader, validation_size): 
        """Initialization."""
        self.model = model
        self.device = torch.device("cuda" if torch.cuda.is_available() else
                                   "cpu")
        self.optimizer = optimizer(self.model.parameters(), lr=0.001)
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.validation_size = validation_size
                
        
    def train_iter(self):
        """Single pass through the training data."""
        self.model.train()
        x = self.train_loader.dataset.tensors[0].to(self.device)
        y = self.train_loader.dataset.tensors[1].to(self.device)
        loss = 0
        self.optimizer.zero_grad()
        for d in range(len(x)):
            means,reconstructions, hidden_states, Z_priors, Zs, Z_posteriors, dhs,_ = self.model(x[d],y[d])
            for i in range(len(reconstructions)):
                L = loss_function(reconstructions[i], y[d][i+1].view(reconstructions[i].size()), Z_priors[i], Z_posteriors[i], var = 1.0)
                loss += L
        loss.backward()
        self.optimizer.step() 
        copymodel = copy.deepcopy(self.model)
        return loss, hidden_states, means, reconstructions, copymodel
    
    def val_iter(self):
        self.model.eval()
        with torch.no_grad():
            val_x = self.test_loader.dataset.tensors[0][:self.validation_size].to(self.device)
            val_y = self.test_loader.dataset.tensors[1][:self.validation_size].to(self.device)
            
            metric = nn.MSELoss()
            val_loss = 0
            
            for i in range(len(val_x)):
                _, reconstructions, hidden_states, _, _, _, _, _ = self.model(val_x[i],val_y[i])
                val_loss += metric(torch.stack(reconstructions).view(-1), val_y[i][1:]).detach().float()
                
        return val_loss 
            
    def train_and_evaluate(self, epochs, params_select = False):
        """Run training and evaluation."""
        self.model.to(self.device)
        model_list=[]
        val_loss_list=[]
        for epoch in range(epochs):
            train_loss, hidden_states,_,_,model = self.train_iter()
            val_loss = self.val_iter()
            model_list.append(model)
            val_loss_list.append(val_loss)
            
            if not params_select:
                print(f"\tEpoch: {epoch}, Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
                            
        return model_list, val_loss_list

            
        
        
def RMSELoss(yhat,y):
    return torch.sqrt(torch.mean((yhat-y)**2))/torch.mean(torch.tensor(y))

# %%
import torch
import os
import pandas as pd
import matplotlib.pyplot as plt
from torch import optim
import torch.nn as nn
import numpy as np




data = pd.read_csv("chickenpox.csv")
data = data[["PEST","BACS","KOMAROM","HEVES","BUDAPEST"]] 

train_steps = 300
val_steps = 150


tw = 15
train_size = train_steps/tw
validation_size = int(val_steps/tw)
test_size = int(len(data)//tw-train_size)

train_loader, test_loader,scaler = create_inout_sequences_chick(data, tw, test_size)

torch.manual_seed(0)
gruVAE = GRUVAE(4,128,128,1,50,4)
vae_trainer = AutoEncoderTrainer(gruVAE, optim.Adam, train_loader, test_loader, validation_size)
model_list, val_loss_list = vae_trainer.train_and_evaluate(150)

val, idx = min((val, idx) for (idx, val) in enumerate(val_loss_list))
model = model_list[idx]



def inverse(y, scaler):
    d = torch.cat([torch.tensor(y),torch.tensor(y),\
                  torch.tensor(y),torch.tensor(y),torch.tensor(y)], dim=-1).numpy()
    d = scaler.inverse_transform(d)
    return d

torch.manual_seed(0)
np.random.seed(0)
prev_x = test_loader.dataset.tensors[0][:validation_size][-1].to("cuda")
prev_y = test_loader.dataset.tensors[1][:validation_size][-1].to("cuda")



def compute_last_h(trials, prev_x, prev_y):
    errors = []
    h_list = []
    metric = nn.MSELoss()
    reconstruction_list = []
    for i in range(trials):
        _, reconstructions, hidden_states, _, _, _, _, _ = model(prev_x, prev_y)
        errors.append(metric(torch.stack(reconstructions).view(-1)[-1], prev_y[1:][-1]))
        h_list.append(hidden_states)
        reconstruction_list.append(torch.stack(reconstructions).detach().to("cpu").numpy())
    val, idx = min((val, idx) for (idx, val) in enumerate(errors))
    return h_list[idx][-1], reconstruction_list[idx]

last_val_h, reconstructions = compute_last_h(500, prev_x, prev_y)


pred_size = 30

new_x = test_loader.dataset.tensors[0][validation_size:].view(-1,4)
new_y = test_loader.dataset.tensors[1][validation_size:].view(-1)
new_y = inverse(new_y.view(-1,1),scaler)[:,4]
# for i in range(len(new_x)):
#   rob = np.random.choice(4,4,replace = False)
#   for j in rob:
#     new_x[i][j]= torch.rand(1)[0]
new_x = new_x.to("cuda")
def make_predictions(model, pred_size, h_start, scaler, new_x):
    predicted_prices = []
    Z_t = torch.zeros(model.Z_size).to("cuda").unsqueeze(0).unsqueeze(0)
    h_t = torch.zeros(model.gru_hidden_size).to("cuda").unsqueeze(0).unsqueeze(0)
    hs = []
    for i in range(pred_size):
        new_Z = model.Z_prior(h_start)
        new_Z = torch.chunk(new_Z, 2, dim=-1)
        Z_std = torch.exp(0.5*new_Z[1])
        new_Z = sample_from_normal(new_Z[0],Z_std)
        Z_t = torch.cat((Z_t,new_Z.unsqueeze(0).unsqueeze(0)),0)
        att,draw = model.laten_att(Z_t[1:],h_start)
        x_prime = torch.cat([att,new_x[i].view(-1).float()])
        h_start,_ = model.run_GRU(x_prime,h_start)
        hs.append(h_start)
    for i in range(pred_size):
        _,predicted_price,_ = model.reconstruct(hs[i])
        predicted_price = predicted_price.to("cpu")
        predicted_price = inverse(predicted_price.view(-1,1),scaler)[:,4]
        predicted_prices.append(max(predicted_price,0))
    
    return predicted_prices,draw
    
def RMSELoss(yhat,y):
    return torch.sqrt(torch.mean((yhat-y)**2))/torch.mean(torch.tensor(y))
def trial(trials, model, hidden_states, pred_size, new_x):
    predictions = []
    upper_90 = []
    lower_90 = []
    upper_95 = []
    lower_95 = []
    mean = []
    for i in range(trials):
        predicted_prices,draw = make_predictions(model, pred_size, hidden_states, scaler, new_x)
        predicted_prices = np.vstack(predicted_prices)
        predictions.append(predicted_prices)
       
    predictions = np.concatenate(predictions, axis=1)
        
    for j in range(pred_size):
        temp = predictions[j]
        upper_90.append(np.percentile(temp,95))
        lower_90.append(np.percentile(temp,5))
        upper_95.append(np.percentile(temp,97.5))
        lower_95.append(np.percentile(temp,2.5))
        mean.append(np.mean(temp))
    print(pred_size,RMSELoss(torch.tensor(mean),new_y[:pred_size]))
    return upper_90, lower_90, upper_95, lower_95, mean,draw


u_90, l_90, u_95, l_95, m,draw = trial(500, model, last_val_h, pred_size, new_x) #COMPUTE MEAN AND CONF INTERVALS

###################################################################################
#RUN THIS BLOCK TO PLOT GRAPH
offset = 200
plt.rcParams["figure.figsize"] = (15,6)
actual_values = data["BUDAPEST"].tolist()[:tw*(len(data)//tw)]
end_idx = val_steps+pred_size+train_steps
start_idx = end_idx-pred_size-val_steps
actual_range = actual_values[start_idx:end_idx]

validation_end = len(actual_range) - pred_size + 1
validation_start = validation_end - val_steps
min_val = min(actual_range[validation_start:validation_end])
max_val = max(actual_range[validation_start:validation_end])


plt.plot(actual_range,color="teal", label="actual")
plt.plot([i+val_steps for i in range(len(m))],m, color="deeppink", label="mean prediction")
plt.fill_between([i+val_steps for i in range(len(m))], u_95, l_95,
                 color='deeppink', alpha=0.2, label="95% confidence interval")
plt.fill_between([i+val_steps for i in range(len(m))], u_90, l_90,
                 color='cyan', alpha=0.2, label="90% confidence interval")

plt.xlabel("observation point")
plt.ylabel("chickenpox cases")

plt.legend(loc="upper right", prop={"size":15})
plt.grid()
ticks,labels = plt.xticks()
ticks = np.array(list(ticks)[1:-1]).astype(int)
labels = ticks+301
plt.xticks(ticks, labels)
plt.savefig("attz.png")
pred_list = [5,10,15,20,25,30,40,50]
for i in pred_list:
  u_90, l_90, u_95, l_95, m,_= trial(500, model, last_val_h, i, new_x)
# Out:
# 	Epoch: 0, Train Loss: 490.1149, Validation Loss: 8.2501
# 	Epoch: 1, Train Loss: 454.1439, Validation Loss: 7.9449
# 	Epoch: 2, Train Loss: 428.5526, Validation Loss: 8.0716
# 	Epoch: 3, Train Loss: 410.0351, Validation Loss: 7.4332
# 	Epoch: 4, Train Loss: 392.0476, Validation Loss: 7.3369
# 	Epoch: 5, Train Loss: 380.5629, Validation Loss: 7.1336
# 	Epoch: 6, Train Loss: 372.5633, Validation Loss: 6.8035
# 	Epoch: 7, Train Loss: 364.0358, Validation Loss: 6.6069
# 	Epoch: 8, Train Loss: 354.6036, Validation Loss: 6.7989
# 	Epoch: 9, Train Loss: 343.1613, Validation Loss: 5.9268
# 	Epoch: 10, Train Loss: 338.9162, Validation Loss: 6.1104
# 	Epoch: 11, Train Loss: 330.1798, Validation Loss: 5.8377
# 	Epoch: 12, Train Loss: 327.3850, Validation Loss: 5.8957
# 	Epoch: 13, Train Loss: 320.3932, Validation Loss: 5.7690
# 	Epoch: 14, Train Loss: 322.0557, Validation Loss: 5.8848
# 	Epoch: 15, Train Loss: 321.8657, Validation Loss: 6.5072
# 	Epoch: 16, Train Loss: 322.7433, Validation Loss: 6.4619
# 	Epoch: 17, Train Loss: 330.3732, Validation Loss: 5.2836
# 	Epoch: 18, Train Loss: 321.1042, Validation Loss: 5.4310
# 	Epoch: 19, Train Loss: 321.7683, Validation Loss: 5.6614
# 	Epoch: 20, Train Loss: 317.4446, Validation Loss: 5.3074
# 	Epoch: 21, Train Loss: 315.1150, Validation Loss: 5.4251
# 	Epoch: 22, Train Loss: 313.2725, Validation Loss: 4.7203
# 	Epoch: 23, Train Loss: 310.5113, Validation Loss: 4.7846
# 	Epoch: 24, Train Loss: 312.7670, Validation Loss: 4.3267
# 	Epoch: 25, Train Loss: 313.8640, Validation Loss: 4.3363
# 	Epoch: 26, Train Loss: 312.5972, Validation Loss: 4.9222
# 	Epoch: 27, Train Loss: 310.3040, Validation Loss: 4.4908
# 	Epoch: 28, Train Loss: 311.4384, Validation Loss: 4.5016
# 	Epoch: 29, Train Loss: 311.3594, Validation Loss: 4.1481
# 	Epoch: 30, Train Loss: 310.8104, Validation Loss: 4.3935
# 	Epoch: 31, Train Loss: 307.3424, Validation Loss: 4.3377
# 	Epoch: 32, Train Loss: 308.4577, Validation Loss: 4.3039
# 	Epoch: 33, Train Loss: 310.0450, Validation Loss: 4.9689
# 	Epoch: 34, Train Loss: 305.7855, Validation Loss: 4.0749
# 	Epoch: 35, Train Loss: 308.2825, Validation Loss: 4.8912
# 	Epoch: 36, Train Loss: 305.5413, Validation Loss: 4.2504
# 	Epoch: 37, Train Loss: 310.9810, Validation Loss: 4.0676
# 	Epoch: 38, Train Loss: 304.8975, Validation Loss: 4.1696
# 	Epoch: 39, Train Loss: 308.2624, Validation Loss: 4.5060
# 	Epoch: 40, Train Loss: 305.2039, Validation Loss: 4.1189
# 	Epoch: 41, Train Loss: 304.0663, Validation Loss: 4.0295
# 	Epoch: 42, Train Loss: 304.9031, Validation Loss: 4.2063
# 	Epoch: 43, Train Loss: 310.6559, Validation Loss: 3.9893
# 	Epoch: 44, Train Loss: 302.5817, Validation Loss: 4.2627
# 	Epoch: 45, Train Loss: 303.9001, Validation Loss: 4.4142
# 	Epoch: 46, Train Loss: 302.0743, Validation Loss: 4.3745
# 	Epoch: 47, Train Loss: 305.1881, Validation Loss: 4.2763
# 	Epoch: 48, Train Loss: 303.7194, Validation Loss: 4.4347
# 	Epoch: 49, Train Loss: 306.2749, Validation Loss: 4.3064
# 	Epoch: 50, Train Loss: 301.3735, Validation Loss: 4.5782
# 	Epoch: 51, Train Loss: 305.4914, Validation Loss: 3.8243
# 	Epoch: 52, Train Loss: 304.0930, Validation Loss: 4.2778
# 	Epoch: 53, Train Loss: 302.7597, Validation Loss: 4.6135
# 	Epoch: 54, Train Loss: 301.7509, Validation Loss: 4.2005
# 	Epoch: 55, Train Loss: 300.3107, Validation Loss: 4.5247
# 	Epoch: 56, Train Loss: 299.4059, Validation Loss: 4.3591
# 	Epoch: 57, Train Loss: 300.6074, Validation Loss: 4.9589
# 	Epoch: 58, Train Loss: 301.3597, Validation Loss: 4.6639
# 	Epoch: 59, Train Loss: 301.3546, Validation Loss: 4.7007
# 	Epoch: 60, Train Loss: 300.4441, Validation Loss: 4.5347
# 	Epoch: 61, Train Loss: 298.9950, Validation Loss: 4.6499
# 	Epoch: 62, Train Loss: 300.5784, Validation Loss: 4.2897
# 	Epoch: 63, Train Loss: 299.0793, Validation Loss: 4.9306
# 	Epoch: 64, Train Loss: 298.9191, Validation Loss: 4.7249
# 	Epoch: 65, Train Loss: 299.9570, Validation Loss: 4.7726
# 	Epoch: 66, Train Loss: 300.4120, Validation Loss: 5.2280
# 	Epoch: 67, Train Loss: 298.6821, Validation Loss: 4.9724
# 	Epoch: 68, Train Loss: 297.1086, Validation Loss: 4.6938
# 	Epoch: 69, Train Loss: 300.7856, Validation Loss: 5.2747
# 	Epoch: 70, Train Loss: 301.5967, Validation Loss: 4.4264
# 	Epoch: 71, Train Loss: 304.1977, Validation Loss: 4.8797
# 	Epoch: 72, Train Loss: 302.2532, Validation Loss: 4.7841
# 	Epoch: 73, Train Loss: 301.1462, Validation Loss: 5.1024
# 	Epoch: 74, Train Loss: 298.9351, Validation Loss: 4.8407
# 	Epoch: 75, Train Loss: 302.1199, Validation Loss: 4.8064
# 	Epoch: 76, Train Loss: 298.0586, Validation Loss: 4.6567
# 	Epoch: 77, Train Loss: 296.7601, Validation Loss: 5.0404
# 	Epoch: 78, Train Loss: 294.6799, Validation Loss: 4.9813
# 	Epoch: 79, Train Loss: 298.4280, Validation Loss: 4.8168
# 	Epoch: 80, Train Loss: 301.5285, Validation Loss: 5.0866
# 	Epoch: 81, Train Loss: 297.7569, Validation Loss: 4.6220
# 	Epoch: 82, Train Loss: 295.3920, Validation Loss: 4.6487
# 	Epoch: 83, Train Loss: 296.0714, Validation Loss: 4.7660
# 	Epoch: 84, Train Loss: 296.7944, Validation Loss: 4.6412
# 	Epoch: 85, Train Loss: 296.5533, Validation Loss: 4.7445
# 	Epoch: 86, Train Loss: 297.0920, Validation Loss: 4.7253
# 	Epoch: 87, Train Loss: 296.5005, Validation Loss: 4.8813
# 	Epoch: 88, Train Loss: 297.1109, Validation Loss: 5.0058
# 	Epoch: 89, Train Loss: 301.8511, Validation Loss: 4.4841
# 	Epoch: 90, Train Loss: 295.7167, Validation Loss: 5.0005
# 	Epoch: 91, Train Loss: 295.9621, Validation Loss: 4.9301
# 	Epoch: 92, Train Loss: 295.8088, Validation Loss: 4.4776
# 	Epoch: 93, Train Loss: 298.1933, Validation Loss: 4.7261
# 	Epoch: 94, Train Loss: 296.1975, Validation Loss: 4.8299
# 	Epoch: 95, Train Loss: 298.8617, Validation Loss: 4.8769
# 	Epoch: 96, Train Loss: 298.0061, Validation Loss: 4.9762
# 	Epoch: 97, Train Loss: 298.7921, Validation Loss: 4.9119
# 	Epoch: 98, Train Loss: 295.8729, Validation Loss: 4.6254
# 	Epoch: 99, Train Loss: 297.1350, Validation Loss: 4.5107
# 	Epoch: 100, Train Loss: 295.1687, Validation Loss: 5.3238
# 	Epoch: 101, Train Loss: 294.8757, Validation Loss: 4.9972
# 	Epoch: 102, Train Loss: 297.7788, Validation Loss: 4.9423
# 	Epoch: 103, Train Loss: 296.5912, Validation Loss: 4.8557
# 	Epoch: 104, Train Loss: 294.3351, Validation Loss: 4.7770
# 	Epoch: 105, Train Loss: 293.9095, Validation Loss: 4.8742
# 	Epoch: 106, Train Loss: 295.8567, Validation Loss: 5.0499
# 	Epoch: 107, Train Loss: 295.6681, Validation Loss: 4.9298
# 	Epoch: 108, Train Loss: 294.0188, Validation Loss: 4.9036
# 	Epoch: 109, Train Loss: 295.4045, Validation Loss: 4.8110
# 	Epoch: 110, Train Loss: 294.1388, Validation Loss: 5.1927
# 	Epoch: 111, Train Loss: 294.6477, Validation Loss: 4.7709
# 	Epoch: 112, Train Loss: 296.3927, Validation Loss: 4.2467
# 	Epoch: 113, Train Loss: 296.8404, Validation Loss: 4.6216
# 	Epoch: 114, Train Loss: 294.4279, Validation Loss: 4.7962
# 	Epoch: 115, Train Loss: 295.6036, Validation Loss: 4.7464
# 	Epoch: 116, Train Loss: 296.4416, Validation Loss: 4.5945
# 	Epoch: 117, Train Loss: 293.9270, Validation Loss: 4.6699
# 	Epoch: 118, Train Loss: 294.4881, Validation Loss: 4.8985
# 	Epoch: 119, Train Loss: 289.7355, Validation Loss: 5.2476
# 	Epoch: 120, Train Loss: 294.8579, Validation Loss: 5.1863
# 	Epoch: 121, Train Loss: 292.6852, Validation Loss: 4.8824
# 	Epoch: 122, Train Loss: 296.1144, Validation Loss: 4.5295
# 	Epoch: 123, Train Loss: 292.9017, Validation Loss: 4.9953
# 	Epoch: 124, Train Loss: 296.2786, Validation Loss: 4.6319
# 	Epoch: 125, Train Loss: 294.4491, Validation Loss: 4.7774
# 	Epoch: 126, Train Loss: 299.7889, Validation Loss: 4.7747
# 	Epoch: 127, Train Loss: 292.0965, Validation Loss: 4.7684
# 	Epoch: 128, Train Loss: 293.7944, Validation Loss: 4.8161
# 	Epoch: 129, Train Loss: 289.6497, Validation Loss: 4.6700
# 	Epoch: 130, Train Loss: 295.6040, Validation Loss: 4.5132
# 	Epoch: 131, Train Loss: 290.2608, Validation Loss: 4.1713
# 	Epoch: 132, Train Loss: 296.8299, Validation Loss: 4.8721
# 	Epoch: 133, Train Loss: 292.7571, Validation Loss: 4.9121
# 	Epoch: 134, Train Loss: 292.9205, Validation Loss: 4.7434
# 	Epoch: 135, Train Loss: 292.3195, Validation Loss: 4.7891
# 	Epoch: 136, Train Loss: 293.6903, Validation Loss: 4.7745
# 	Epoch: 137, Train Loss: 293.3952, Validation Loss: 4.8259
# 	Epoch: 138, Train Loss: 294.2433, Validation Loss: 4.6005
# 	Epoch: 139, Train Loss: 294.6592, Validation Loss: 4.5842
# 	Epoch: 140, Train Loss: 292.6612, Validation Loss: 4.8699
# 	Epoch: 141, Train Loss: 293.4733, Validation Loss: 4.8936
# 	Epoch: 142, Train Loss: 289.3868, Validation Loss: 4.5033
# 	Epoch: 143, Train Loss: 292.9151, Validation Loss: 4.4776
# 	Epoch: 144, Train Loss: 291.5212, Validation Loss: 4.6628
# 	Epoch: 145, Train Loss: 290.2384, Validation Loss: 4.6864
# 	Epoch: 146, Train Loss: 293.3778, Validation Loss: 4.6206
# 	Epoch: 147, Train Loss: 291.7225, Validation Loss: 4.9425
# 	Epoch: 148, Train Loss: 288.4769, Validation Loss: 4.5360
# 	Epoch: 149, Train Loss: 289.8049, Validation Loss: 4.8222
# 30 tensor(0.5612, dtype=torch.float64)
# 5 tensor(0.6180, dtype=torch.float64)
# 10 tensor(0.5911, dtype=torch.float64)
# 15 tensor(0.5890, dtype=torch.float64)
# 20 tensor(0.6115, dtype=torch.float64)
# 25 tensor(0.6693, dtype=torch.float64)
# 30 tensor(0.5600, dtype=torch.float64)
# 40 tensor(0.7591, dtype=torch.float64)
# 50 tensor(0.6779, dtype=torch.float64)

# %%
def RMSELoss(yhat,y):
    return torch.sqrt(torch.mean((yhat-y)**2))/torch.mean(torch.tensor(y))
# # os.chdir("C:/Users/tonyz/Desktop/GRUVAE/model")
# # import gruvae
# # import train


# # # os.chdir("C:/Users/tonyz/Desktop/GRUVAE/data/usingmean")
# from torch import optim
data = pd.read_csv("AMZN_put.csv").dropna()
data = data[["Stock","Option"]] 

train_steps = 300
val_steps = 30

tw = 10
train_size = train_steps/tw
validation_size = int(val_steps/tw)
test_size = int(len(data)//tw-train_size)

train_loader, test_loader,scaler = create_inout_sequences_opt(data, tw, test_size)

torch.manual_seed(0)
gruVAE = GRUVAE(1,64,64,1,50,4)
vae_trainer = AutoEncoderTrainer(gruVAE, optim.Adam, train_loader, test_loader, validation_size)
model_list, val_loss_list = vae_trainer.train_and_evaluate(300)

val, idx = min((val, idx) for (idx, val) in enumerate(val_loss_list))
model = model_list[idx]



def inverse(y, scaler):
    d = torch.cat([torch.tensor(y),torch.tensor(y)], dim=-1).numpy()
    d = scaler.inverse_transform(d)
    return d


torch.manual_seed(0)

prev_x = test_loader.dataset.tensors[0][:validation_size][-1].to("cuda")
prev_y = test_loader.dataset.tensors[1][:validation_size][-1].to("cuda")




def compute_last_h(trials, prev_x, prev_y):
    errors = []
    h_list = []
    hs_list = []
    metric = nn.MSELoss()
    reconstruction_list = []
    for i in range(trials):
        _, reconstructions, hidden_states, _, _, _, _, _ = model(prev_x, prev_y)
        errors.append(metric(torch.stack(reconstructions).view(-1)[-1], prev_y[1:][-1]))
        h_list.append(hidden_states)
        # hs_list.append(hs)

        reconstruction_list.append(torch.stack(reconstructions).detach().to("cpu").numpy())
    val, idx = min((val, idx) for (idx, val) in enumerate(errors))
    return h_list[idx][-1], reconstruction_list[idx]
last_val_h, reconstructions = compute_last_h(500, prev_x, prev_y)


pred_size = 30
new_x = test_loader.dataset.tensors[0][validation_size:].view(-1,1).to("cuda")
new_y = test_loader.dataset.tensors[1][validation_size:].view(-1)
new_y = inverse(new_y.view(-1,1),scaler)[:,1]

def make_predictions(model, pred_size, h_start, scaler, new_x):
    predicted_prices = []
    Z_t = torch.zeros(model.Z_size).to("cuda").unsqueeze(0).unsqueeze(0)
    h_t = torch.zeros(model.gru_hidden_size).to("cuda").unsqueeze(0).unsqueeze(0)
    hs = []
    for i in range(pred_size):
        new_Z = model.Z_prior(h_start)
        new_Z = torch.chunk(new_Z, 2, dim=-1)
        Z_std = torch.exp(0.5*new_Z[1])
        new_Z = sample_from_normal(new_Z[0],Z_std)

        Z_t = torch.cat((Z_t,new_Z.unsqueeze(0).unsqueeze(0)),0)
        att,draw = model.laten_att(Z_t[1:],h_start)
        x_prime = torch.cat([att,new_x[i].view(-1).float()])
        # x_prime = torch.cat([new_Z, new_x[i].view(-1).float()])
        h_start,_ = model.run_GRU(x_prime,h_start)
        # h_t = torch.cat((h_t,h_start.unsqueeze(0).unsqueeze(0)),1)
        hs.append(h_start)
    # tem = model.mha(Z_t[:,1:],Z_t[:,1:],h_t[:,1:],None)[0][0]
    for i in range(pred_size):
        _,predicted_price,_ = model.reconstruct(hs[i])
        predicted_price = predicted_price.to("cpu")
        predicted_price = inverse(predicted_price.view(-1,1),scaler)[:,1]
        predicted_prices.append(max(predicted_price,0))
    
    return predicted_prices,draw
def trial(trials, model, hidden_states, pred_size, new_x):
    predictions = []
    upper_90 = []
    lower_90 = []
    upper_95 = []
    lower_95 = []
    mean = []
    for i in range(trials):
        predicted_prices,_ = make_predictions(model, pred_size, hidden_states, scaler, new_x)
        predicted_prices = np.vstack(predicted_prices)
        predictions.append(predicted_prices)
       
    predictions = np.concatenate(predictions, axis=1)
        
    for j in range(pred_size):
        temp = predictions[j]
        upper_90.append(np.percentile(temp,95))
        lower_90.append(np.percentile(temp,5))
        upper_95.append(np.percentile(temp,97.5))
        lower_95.append(np.percentile(temp,2.5))
        mean.append(np.mean(temp))
    print(pred_size,RMSELoss(torch.tensor(mean),new_y[:pred_size]))

    return upper_90, lower_90, upper_95, lower_95, mean


u_90, l_90, u_95, l_95, m = trial(500, model, last_val_h, pred_size, new_x)

#############################################################################
#run this block to plot graph
offset = 200
plt.rcParams["figure.figsize"] = (15,6)
actual_values = data["Option"].tolist()[:tw*(len(data)//tw)]

end_idx = train_steps+val_steps+pred_size
actual_range = actual_values[:end_idx]

validation_end = len(actual_range) - pred_size + 1
validation_start = validation_end - val_steps
min_val = min(actual_range[validation_start:validation_end])
max_val = max(actual_range[validation_start:validation_end])


plt.plot(actual_range,color="teal", label="actual")
plt.plot([i+train_steps+val_steps for i in range(len(m))],m, color="deeppink", label="mean prediction")
plt.fill_between([i+train_steps+val_steps for i in range(len(m))], u_95, l_95,
                 color='deeppink', alpha=0.2, label="95% confidence interval")
plt.fill_between([i+train_steps+val_steps for i in range(len(m))], u_90, l_90,
                 color='cyan', alpha=0.2, label="90% confidence interval")

plt.xlabel("Time/min")
plt.ylabel("Option Price")
plt.legend(loc="upper left", prop={"size":15})
plt.grid()
ticks,labels = plt.xticks()
ticks = np.array(list(ticks)[1:-1]).astype(int)
labels = ticks+5
plt.xticks(ticks, labels)
# Out:
# 	Epoch: 0, Train Loss: 535.4462, Validation Loss: 1.6888
# 	Epoch: 1, Train Loss: 509.7369, Validation Loss: 1.6802
# 	Epoch: 2, Train Loss: 486.1922, Validation Loss: 1.5653
# 	Epoch: 3, Train Loss: 465.2128, Validation Loss: 1.5583
# 	Epoch: 4, Train Loss: 450.0343, Validation Loss: 1.5288
# 	Epoch: 5, Train Loss: 435.1007, Validation Loss: 1.4750
# 	Epoch: 6, Train Loss: 422.7797, Validation Loss: 1.4381
# 	Epoch: 7, Train Loss: 412.5728, Validation Loss: 1.4859
# 	Epoch: 8, Train Loss: 402.7244, Validation Loss: 1.3233
# 	Epoch: 9, Train Loss: 393.0270, Validation Loss: 1.4181
# 	Epoch: 10, Train Loss: 385.5818, Validation Loss: 1.3339
# 	Epoch: 11, Train Loss: 380.5770, Validation Loss: 1.1531
# 	Epoch: 12, Train Loss: 376.4883, Validation Loss: 1.2367
# 	Epoch: 13, Train Loss: 372.4484, Validation Loss: 1.2094
# 	Epoch: 14, Train Loss: 367.6687, Validation Loss: 1.3763
# 	Epoch: 15, Train Loss: 364.2113, Validation Loss: 0.9527
# 	Epoch: 16, Train Loss: 358.0270, Validation Loss: 1.0471
# 	Epoch: 17, Train Loss: 352.4583, Validation Loss: 0.9104
# 	Epoch: 18, Train Loss: 344.9971, Validation Loss: 1.0643
# 	Epoch: 19, Train Loss: 342.4565, Validation Loss: 1.0276
# 	Epoch: 20, Train Loss: 332.5525, Validation Loss: 0.7523
# 	Epoch: 21, Train Loss: 334.8470, Validation Loss: 0.9859
# 	Epoch: 22, Train Loss: 324.1770, Validation Loss: 1.3507
# 	Epoch: 23, Train Loss: 320.6804, Validation Loss: 0.9918
# 	Epoch: 24, Train Loss: 312.4460, Validation Loss: 0.6986
# 	Epoch: 25, Train Loss: 307.6442, Validation Loss: 0.6081
# 	Epoch: 26, Train Loss: 304.7595, Validation Loss: 0.6388
# 	Epoch: 27, Train Loss: 306.7795, Validation Loss: 0.6089
# 	Epoch: 28, Train Loss: 301.3213, Validation Loss: 0.4197
# 	Epoch: 29, Train Loss: 288.0278, Validation Loss: 0.2390
# 	Epoch: 30, Train Loss: 290.6017, Validation Loss: 0.2225
# 	Epoch: 31, Train Loss: 285.0456, Validation Loss: 0.3788
# 	Epoch: 32, Train Loss: 276.2146, Validation Loss: 0.2589
# 	Epoch: 33, Train Loss: 283.9800, Validation Loss: 0.1874
# 	Epoch: 34, Train Loss: 282.8852, Validation Loss: 0.2235
# 	Epoch: 35, Train Loss: 282.5971, Validation Loss: 0.1127
# 	Epoch: 36, Train Loss: 275.2230, Validation Loss: 0.3793
# 	Epoch: 37, Train Loss: 278.7560, Validation Loss: 0.4283
# 	Epoch: 38, Train Loss: 273.2913, Validation Loss: 0.5660
# 	Epoch: 39, Train Loss: 277.1225, Validation Loss: 0.2734
# 	Epoch: 40, Train Loss: 273.5135, Validation Loss: 0.3785
# 	Epoch: 41, Train Loss: 275.7882, Validation Loss: 0.1543
# 	Epoch: 42, Train Loss: 271.6203, Validation Loss: 0.1376
# 	Epoch: 43, Train Loss: 269.1310, Validation Loss: 0.1074
# 	Epoch: 44, Train Loss: 267.5293, Validation Loss: 0.1894
# 	Epoch: 45, Train Loss: 266.9389, Validation Loss: 0.0903
# 	Epoch: 46, Train Loss: 263.9940, Validation Loss: 0.1979
# 	Epoch: 47, Train Loss: 265.9198, Validation Loss: 0.1087
# 	Epoch: 48, Train Loss: 263.1127, Validation Loss: 0.1028
# 	Epoch: 49, Train Loss: 262.9361, Validation Loss: 0.0759
# 	Epoch: 50, Train Loss: 262.8843, Validation Loss: 0.0888
# 	Epoch: 51, Train Loss: 262.5045, Validation Loss: 0.1489
# 	Epoch: 52, Train Loss: 263.8965, Validation Loss: 0.0602
# 	Epoch: 53, Train Loss: 262.6419, Validation Loss: 0.1392
# 	Epoch: 54, Train Loss: 260.8366, Validation Loss: 0.1003
# 	Epoch: 55, Train Loss: 261.6281, Validation Loss: 0.1270
# 	Epoch: 56, Train Loss: 260.5882, Validation Loss: 0.1005
# 	Epoch: 57, Train Loss: 259.7604, Validation Loss: 0.0933
# 	Epoch: 58, Train Loss: 259.0395, Validation Loss: 0.0889
# 	Epoch: 59, Train Loss: 259.3928, Validation Loss: 0.1217
# 	Epoch: 60, Train Loss: 259.5408, Validation Loss: 0.1528
# 	Epoch: 61, Train Loss: 259.8588, Validation Loss: 0.1049
# 	Epoch: 62, Train Loss: 259.0205, Validation Loss: 0.1711
# 	Epoch: 63, Train Loss: 257.7952, Validation Loss: 0.2238
# 	Epoch: 64, Train Loss: 258.3665, Validation Loss: 0.1358
# 	Epoch: 65, Train Loss: 258.6838, Validation Loss: 0.1243
# 	Epoch: 66, Train Loss: 258.4344, Validation Loss: 0.1827
# 	Epoch: 67, Train Loss: 256.9017, Validation Loss: 0.1115
# 	Epoch: 68, Train Loss: 257.7277, Validation Loss: 0.0665
# 	Epoch: 69, Train Loss: 258.1843, Validation Loss: 0.1308
# 	Epoch: 70, Train Loss: 256.8189, Validation Loss: 0.0937
# 	Epoch: 71, Train Loss: 256.1242, Validation Loss: 0.0820
# 	Epoch: 72, Train Loss: 255.6604, Validation Loss: 0.1252
# 	Epoch: 73, Train Loss: 255.9284, Validation Loss: 0.0581
# 	Epoch: 74, Train Loss: 256.6105, Validation Loss: 0.0775
# 	Epoch: 75, Train Loss: 256.1960, Validation Loss: 0.0950
# 	Epoch: 76, Train Loss: 254.9449, Validation Loss: 0.1135
# 	Epoch: 77, Train Loss: 255.5445, Validation Loss: 0.0633
# 	Epoch: 78, Train Loss: 255.9666, Validation Loss: 0.0826
# 	Epoch: 79, Train Loss: 255.1935, Validation Loss: 0.0779
# 	Epoch: 80, Train Loss: 255.0767, Validation Loss: 0.0570
# 	Epoch: 81, Train Loss: 255.4503, Validation Loss: 0.0559
# 	Epoch: 82, Train Loss: 255.1276, Validation Loss: 0.0536
# 	Epoch: 83, Train Loss: 254.6342, Validation Loss: 0.1066
# 	Epoch: 84, Train Loss: 254.3212, Validation Loss: 0.0995
# 	Epoch: 85, Train Loss: 254.1471, Validation Loss: 0.1071
# 	Epoch: 86, Train Loss: 254.6291, Validation Loss: 0.1013
# 	Epoch: 87, Train Loss: 254.2791, Validation Loss: 0.1072
# 	Epoch: 88, Train Loss: 254.5786, Validation Loss: 0.0752
# 	Epoch: 89, Train Loss: 253.8254, Validation Loss: 0.0478
# 	Epoch: 90, Train Loss: 254.2768, Validation Loss: 0.0775
# 	Epoch: 91, Train Loss: 254.1914, Validation Loss: 0.0816
# 	Epoch: 92, Train Loss: 254.3107, Validation Loss: 0.0475
# 	Epoch: 93, Train Loss: 252.9387, Validation Loss: 0.0623
# 	Epoch: 94, Train Loss: 253.7137, Validation Loss: 0.0609
# 	Epoch: 95, Train Loss: 252.9379, Validation Loss: 0.0587
# 	Epoch: 96, Train Loss: 253.0454, Validation Loss: 0.0666
# 	Epoch: 97, Train Loss: 253.4713, Validation Loss: 0.0719
# 	Epoch: 98, Train Loss: 253.4839, Validation Loss: 0.0330
# 	Epoch: 99, Train Loss: 253.3374, Validation Loss: 0.0387
# 	Epoch: 100, Train Loss: 253.0298, Validation Loss: 0.0686
# 	Epoch: 101, Train Loss: 252.4087, Validation Loss: 0.0645
# 	Epoch: 102, Train Loss: 252.7168, Validation Loss: 0.0846
# 	Epoch: 103, Train Loss: 252.6215, Validation Loss: 0.0750
# 	Epoch: 104, Train Loss: 252.8114, Validation Loss: 0.0542
# 	Epoch: 105, Train Loss: 252.3056, Validation Loss: 0.0677
# 	Epoch: 106, Train Loss: 251.9100, Validation Loss: 0.0297
# 	Epoch: 107, Train Loss: 251.9201, Validation Loss: 0.0363
# 	Epoch: 108, Train Loss: 252.1961, Validation Loss: 0.0557
# 	Epoch: 109, Train Loss: 251.8886, Validation Loss: 0.0627
# 	Epoch: 110, Train Loss: 252.4937, Validation Loss: 0.0608
# 	Epoch: 111, Train Loss: 251.9813, Validation Loss: 0.0634
# 	Epoch: 112, Train Loss: 251.7884, Validation Loss: 0.0646
# 	Epoch: 113, Train Loss: 252.3057, Validation Loss: 0.0670
# 	Epoch: 114, Train Loss: 251.5882, Validation Loss: 0.0543
# 	Epoch: 115, Train Loss: 251.8008, Validation Loss: 0.0371
# 	Epoch: 116, Train Loss: 251.5310, Validation Loss: 0.0638
# 	Epoch: 117, Train Loss: 251.7326, Validation Loss: 0.0364
# 	Epoch: 118, Train Loss: 251.7105, Validation Loss: 0.0458
# 	Epoch: 119, Train Loss: 251.8159, Validation Loss: 0.0675
# 	Epoch: 120, Train Loss: 251.1770, Validation Loss: 0.0369
# 	Epoch: 121, Train Loss: 251.5872, Validation Loss: 0.0386
# 	Epoch: 122, Train Loss: 251.2552, Validation Loss: 0.0541
# 	Epoch: 123, Train Loss: 251.4746, Validation Loss: 0.0523
# 	Epoch: 124, Train Loss: 251.2549, Validation Loss: 0.0572
# 	Epoch: 125, Train Loss: 251.0310, Validation Loss: 0.0254
# 	Epoch: 126, Train Loss: 250.9686, Validation Loss: 0.0429
# 	Epoch: 127, Train Loss: 251.6005, Validation Loss: 0.0528
# 	Epoch: 128, Train Loss: 251.1825, Validation Loss: 0.0734
# 	Epoch: 129, Train Loss: 251.1990, Validation Loss: 0.0296
# 	Epoch: 130, Train Loss: 250.7586, Validation Loss: 0.0808
# 	Epoch: 131, Train Loss: 251.3567, Validation Loss: 0.0278
# 	Epoch: 132, Train Loss: 250.6801, Validation Loss: 0.0471
# 	Epoch: 133, Train Loss: 251.0799, Validation Loss: 0.0511
# 	Epoch: 134, Train Loss: 251.7401, Validation Loss: 0.0481
# 	Epoch: 135, Train Loss: 250.8456, Validation Loss: 0.0452
# 	Epoch: 136, Train Loss: 250.7478, Validation Loss: 0.0586
# 	Epoch: 137, Train Loss: 250.5391, Validation Loss: 0.0227
# 	Epoch: 138, Train Loss: 250.6390, Validation Loss: 0.0478
# 	Epoch: 139, Train Loss: 250.5151, Validation Loss: 0.0254
# 	Epoch: 140, Train Loss: 250.6617, Validation Loss: 0.0385
# 	Epoch: 141, Train Loss: 251.1451, Validation Loss: 0.0330
# 	Epoch: 142, Train Loss: 250.7034, Validation Loss: 0.0359
# 	Epoch: 143, Train Loss: 250.2609, Validation Loss: 0.0486
# 	Epoch: 144, Train Loss: 250.2000, Validation Loss: 0.0207
# 	Epoch: 145, Train Loss: 250.5134, Validation Loss: 0.0258
# 	Epoch: 146, Train Loss: 250.6436, Validation Loss: 0.0336
# 	Epoch: 147, Train Loss: 250.3727, Validation Loss: 0.0315
# 	Epoch: 148, Train Loss: 250.6895, Validation Loss: 0.0318
# 	Epoch: 149, Train Loss: 250.6841, Validation Loss: 0.0535
# 	Epoch: 150, Train Loss: 250.5960, Validation Loss: 0.0387
# 	Epoch: 151, Train Loss: 250.4984, Validation Loss: 0.0170
# 	Epoch: 152, Train Loss: 250.2362, Validation Loss: 0.0623
# 	Epoch: 153, Train Loss: 249.9832, Validation Loss: 0.0243
# 	Epoch: 154, Train Loss: 250.4173, Validation Loss: 0.0370
# 	Epoch: 155, Train Loss: 250.3057, Validation Loss: 0.0313
# 	Epoch: 156, Train Loss: 250.2110, Validation Loss: 0.0211
# 	Epoch: 157, Train Loss: 250.3709, Validation Loss: 0.0192
# 	Epoch: 158, Train Loss: 250.3045, Validation Loss: 0.0234
# 	Epoch: 159, Train Loss: 250.6446, Validation Loss: 0.0359
# 	Epoch: 160, Train Loss: 250.3203, Validation Loss: 0.0544
# 	Epoch: 161, Train Loss: 250.3301, Validation Loss: 0.0320
# 	Epoch: 162, Train Loss: 250.1041, Validation Loss: 0.0216
# 	Epoch: 163, Train Loss: 250.4162, Validation Loss: 0.0155
# 	Epoch: 164, Train Loss: 249.9939, Validation Loss: 0.0252
# 	Epoch: 165, Train Loss: 250.4901, Validation Loss: 0.0412
# 	Epoch: 166, Train Loss: 250.0003, Validation Loss: 0.0452
# 	Epoch: 167, Train Loss: 250.0486, Validation Loss: 0.0222
# 	Epoch: 168, Train Loss: 249.8831, Validation Loss: 0.0322
# 	Epoch: 169, Train Loss: 250.1679, Validation Loss: 0.0143
# 	Epoch: 170, Train Loss: 250.1195, Validation Loss: 0.0545
# 	Epoch: 171, Train Loss: 249.6246, Validation Loss: 0.0247
# 	Epoch: 172, Train Loss: 250.0920, Validation Loss: 0.0167
# 	Epoch: 173, Train Loss: 250.0066, Validation Loss: 0.0222
# 	Epoch: 174, Train Loss: 250.1090, Validation Loss: 0.0360
# 	Epoch: 175, Train Loss: 249.9478, Validation Loss: 0.0143
# 	Epoch: 176, Train Loss: 250.0356, Validation Loss: 0.0411
# 	Epoch: 177, Train Loss: 250.1660, Validation Loss: 0.0425
# 	Epoch: 178, Train Loss: 250.1881, Validation Loss: 0.0122
# 	Epoch: 179, Train Loss: 249.6269, Validation Loss: 0.0128
# 	Epoch: 180, Train Loss: 249.8571, Validation Loss: 0.0219
# 	Epoch: 181, Train Loss: 249.9098, Validation Loss: 0.0339
# 	Epoch: 182, Train Loss: 249.7812, Validation Loss: 0.0118
# 	Epoch: 183, Train Loss: 249.8236, Validation Loss: 0.0182
# 	Epoch: 184, Train Loss: 250.2453, Validation Loss: 0.0274
# 	Epoch: 185, Train Loss: 249.8370, Validation Loss: 0.0281
# 	Epoch: 186, Train Loss: 249.9107, Validation Loss: 0.0168
# 	Epoch: 187, Train Loss: 250.0013, Validation Loss: 0.0201
# 	Epoch: 188, Train Loss: 249.8140, Validation Loss: 0.0168
# 	Epoch: 189, Train Loss: 249.6384, Validation Loss: 0.0367
# 	Epoch: 190, Train Loss: 249.6471, Validation Loss: 0.0320
# 	Epoch: 191, Train Loss: 249.5896, Validation Loss: 0.0306
# 	Epoch: 192, Train Loss: 249.6370, Validation Loss: 0.0399
# 	Epoch: 193, Train Loss: 250.0625, Validation Loss: 0.0294
# 	Epoch: 194, Train Loss: 249.6349, Validation Loss: 0.0559
# 	Epoch: 195, Train Loss: 250.0472, Validation Loss: 0.0263
# 	Epoch: 196, Train Loss: 249.3482, Validation Loss: 0.0152
# 	Epoch: 197, Train Loss: 249.6734, Validation Loss: 0.0214
# 	Epoch: 198, Train Loss: 249.8139, Validation Loss: 0.0114
# 	Epoch: 199, Train Loss: 249.4779, Validation Loss: 0.0284
# 	Epoch: 200, Train Loss: 249.4538, Validation Loss: 0.0214
# 	Epoch: 201, Train Loss: 249.4719, Validation Loss: 0.0359
# 	Epoch: 202, Train Loss: 249.6226, Validation Loss: 0.0353
# 	Epoch: 203, Train Loss: 249.5041, Validation Loss: 0.0157
# 	Epoch: 204, Train Loss: 249.5631, Validation Loss: 0.0087
# 	Epoch: 205, Train Loss: 249.4995, Validation Loss: 0.0098
# 	Epoch: 206, Train Loss: 249.5540, Validation Loss: 0.0088
# 	Epoch: 207, Train Loss: 249.5374, Validation Loss: 0.0109
# 	Epoch: 208, Train Loss: 249.7365, Validation Loss: 0.0152
# 	Epoch: 209, Train Loss: 249.4464, Validation Loss: 0.0116
# 	Epoch: 210, Train Loss: 249.6449, Validation Loss: 0.0147
# 	Epoch: 211, Train Loss: 249.3627, Validation Loss: 0.0103
# 	Epoch: 212, Train Loss: 249.5500, Validation Loss: 0.0137
# 	Epoch: 213, Train Loss: 249.4155, Validation Loss: 0.0297
# 	Epoch: 214, Train Loss: 249.2854, Validation Loss: 0.0378
# 	Epoch: 215, Train Loss: 249.2773, Validation Loss: 0.0175
# 	Epoch: 216, Train Loss: 249.4069, Validation Loss: 0.0292
# 	Epoch: 217, Train Loss: 249.1756, Validation Loss: 0.0266
# 	Epoch: 218, Train Loss: 249.3898, Validation Loss: 0.0240
# 	Epoch: 219, Train Loss: 249.3491, Validation Loss: 0.0089
# 	Epoch: 220, Train Loss: 249.2222, Validation Loss: 0.0383
# 	Epoch: 221, Train Loss: 249.4658, Validation Loss: 0.0268
# 	Epoch: 222, Train Loss: 249.2325, Validation Loss: 0.0256
# 	Epoch: 223, Train Loss: 249.3697, Validation Loss: 0.0132
# 	Epoch: 224, Train Loss: 249.3536, Validation Loss: 0.0166
# 	Epoch: 225, Train Loss: 249.5573, Validation Loss: 0.0314
# 	Epoch: 226, Train Loss: 249.3951, Validation Loss: 0.0136
# 	Epoch: 227, Train Loss: 249.5633, Validation Loss: 0.0127
# 	Epoch: 228, Train Loss: 249.1912, Validation Loss: 0.0213
# 	Epoch: 229, Train Loss: 249.2052, Validation Loss: 0.0144
# 	Epoch: 230, Train Loss: 249.9837, Validation Loss: 0.0095
# 	Epoch: 231, Train Loss: 249.2701, Validation Loss: 0.0524
# 	Epoch: 232, Train Loss: 249.5332, Validation Loss: 0.0160
# 	Epoch: 233, Train Loss: 249.1825, Validation Loss: 0.0211
# 	Epoch: 234, Train Loss: 249.1699, Validation Loss: 0.0169
# 	Epoch: 235, Train Loss: 249.2878, Validation Loss: 0.0097
# 	Epoch: 236, Train Loss: 249.4351, Validation Loss: 0.0302
# 	Epoch: 237, Train Loss: 249.3213, Validation Loss: 0.0259
# 	Epoch: 238, Train Loss: 249.2611, Validation Loss: 0.0235
# 	Epoch: 239, Train Loss: 249.1342, Validation Loss: 0.0293
# 	Epoch: 240, Train Loss: 249.2222, Validation Loss: 0.0139
# 	Epoch: 241, Train Loss: 249.2324, Validation Loss: 0.0205
# 	Epoch: 242, Train Loss: 249.5031, Validation Loss: 0.0200
# 	Epoch: 243, Train Loss: 249.2273, Validation Loss: 0.0134
# 	Epoch: 244, Train Loss: 249.0510, Validation Loss: 0.0196
# 	Epoch: 245, Train Loss: 249.2161, Validation Loss: 0.0190
# 	Epoch: 246, Train Loss: 249.1837, Validation Loss: 0.0133
# 	Epoch: 247, Train Loss: 249.0425, Validation Loss: 0.0186
# 	Epoch: 248, Train Loss: 249.4530, Validation Loss: 0.0210
# 	Epoch: 249, Train Loss: 249.0854, Validation Loss: 0.0166
# 	Epoch: 250, Train Loss: 249.2823, Validation Loss: 0.0150
# 	Epoch: 251, Train Loss: 249.2154, Validation Loss: 0.0206
# 	Epoch: 252, Train Loss: 249.1783, Validation Loss: 0.0106
# 	Epoch: 253, Train Loss: 248.9669, Validation Loss: 0.0193
# 	Epoch: 254, Train Loss: 248.9807, Validation Loss: 0.0130
# 	Epoch: 255, Train Loss: 249.1133, Validation Loss: 0.0086
# 	Epoch: 256, Train Loss: 248.9146, Validation Loss: 0.0229
# 	Epoch: 257, Train Loss: 249.1882, Validation Loss: 0.0321
# 	Epoch: 258, Train Loss: 249.2509, Validation Loss: 0.0089
# 	Epoch: 259, Train Loss: 249.3030, Validation Loss: 0.0059
# 	Epoch: 260, Train Loss: 249.0428, Validation Loss: 0.0188
# 	Epoch: 261, Train Loss: 249.1102, Validation Loss: 0.0160
# 	Epoch: 262, Train Loss: 249.1203, Validation Loss: 0.0174
# 	Epoch: 263, Train Loss: 249.2263, Validation Loss: 0.0064
# 	Epoch: 264, Train Loss: 248.8577, Validation Loss: 0.0345
# 	Epoch: 265, Train Loss: 249.0011, Validation Loss: 0.0141
# 	Epoch: 266, Train Loss: 248.9469, Validation Loss: 0.0157
# 	Epoch: 267, Train Loss: 249.1424, Validation Loss: 0.0202
# 	Epoch: 268, Train Loss: 248.7440, Validation Loss: 0.0294
# 	Epoch: 269, Train Loss: 248.9517, Validation Loss: 0.0142
# 	Epoch: 270, Train Loss: 248.8783, Validation Loss: 0.0249
# 	Epoch: 271, Train Loss: 249.1348, Validation Loss: 0.0206
# 	Epoch: 272, Train Loss: 249.3339, Validation Loss: 0.0192
# 	Epoch: 273, Train Loss: 248.9134, Validation Loss: 0.0088
# 	Epoch: 274, Train Loss: 249.1614, Validation Loss: 0.0225
# 	Epoch: 275, Train Loss: 248.9830, Validation Loss: 0.0129
# 	Epoch: 276, Train Loss: 249.2288, Validation Loss: 0.0194
# 	Epoch: 277, Train Loss: 249.1263, Validation Loss: 0.0084
# 	Epoch: 278, Train Loss: 249.1401, Validation Loss: 0.0124
# 	Epoch: 279, Train Loss: 248.9426, Validation Loss: 0.0083
# 	Epoch: 280, Train Loss: 248.9757, Validation Loss: 0.0198
# 	Epoch: 281, Train Loss: 248.8870, Validation Loss: 0.0128
# 	Epoch: 282, Train Loss: 249.0081, Validation Loss: 0.0121
# 	Epoch: 283, Train Loss: 249.0257, Validation Loss: 0.0116
# 	Epoch: 284, Train Loss: 248.9002, Validation Loss: 0.0273
# 	Epoch: 285, Train Loss: 249.0865, Validation Loss: 0.0118
# 	Epoch: 286, Train Loss: 249.0482, Validation Loss: 0.0097
# 	Epoch: 287, Train Loss: 248.9731, Validation Loss: 0.0092
# 	Epoch: 288, Train Loss: 248.8468, Validation Loss: 0.0138
# 	Epoch: 289, Train Loss: 248.9593, Validation Loss: 0.0149
# 	Epoch: 290, Train Loss: 248.8664, Validation Loss: 0.0267
# 	Epoch: 291, Train Loss: 248.8673, Validation Loss: 0.0122
# 	Epoch: 292, Train Loss: 248.9338, Validation Loss: 0.0099
# 	Epoch: 293, Train Loss: 249.1095, Validation Loss: 0.0081
# 	Epoch: 294, Train Loss: 249.0476, Validation Loss: 0.0119
# 	Epoch: 295, Train Loss: 248.9292, Validation Loss: 0.0066
# 	Epoch: 296, Train Loss: 248.9978, Validation Loss: 0.0213
# 	Epoch: 297, Train Loss: 248.9168, Validation Loss: 0.0180
# 	Epoch: 298, Train Loss: 248.9150, Validation Loss: 0.0188
# 	Epoch: 299, Train Loss: 248.8087, Validation Loss: 0.0143
# 30 tensor(0.0043, dtype=torch.float64)
# ([<matplotlib.axis.XTick at 0x7f27a266d8d0>,
#   <matplotlib.axis.XTick at 0x7f27a266d490>,
#   <matplotlib.axis.XTick at 0x7f27a2679fd0>,
#   <matplotlib.axis.XTick at 0x7f27a239cd10>,
#   <matplotlib.axis.XTick at 0x7f27aae62250>,
#   <matplotlib.axis.XTick at 0x7f27aae62f50>,
#   <matplotlib.axis.XTick at 0x7f27a239c850>,
#   <matplotlib.axis.XTick at 0x7f27aae62090>],
#  [Text(0, 0, '5'),
#   Text(0, 0, '55'),
#   Text(0, 0, '105'),
#   Text(0, 0, '155'),
#   Text(0, 0, '205'),
#   Text(0, 0, '255'),
#   Text(0, 0, '305'),
#   Text(0, 0, '355')])

# %%
import torch
import os
import pandas as pd
import matplotlib.pyplot as plt
from torch import optim
import torch.nn as nn
import numpy as np



data = pd.read_csv("beijingpm.csv")
data = data[["Temperature","Pressure","WindSpeed","DewPoint","Rainfall","Snow","pm2.5"]] 


train_steps = 1200
val_steps = 200

tw = 10
train_size = train_steps/tw
validation_size = int(val_steps/tw)
test_size = int(len(data)//tw-train_size)


train_loader, test_loader,scaler = create_inout_sequences_pm(data, tw, test_size)

torch.manual_seed(0)
gruVAE = GRUVAE(6,64,64,1,50,4)
vae_trainer = AutoEncoderTrainer(gruVAE, optim.Adam, train_loader, test_loader, validation_size)
model_list, val_loss_list = vae_trainer.train_and_evaluate(300) 


val, idx = min((val, idx) for (idx, val) in enumerate(val_loss_list))
model = model_list[idx]



def inverse(y, scaler):
    d = torch.cat([torch.tensor(y),torch.tensor(y),\
                  torch.tensor(y),torch.tensor(y),torch.tensor(y),torch.tensor(y),torch.tensor(y)], dim=-1).numpy()
    d = scaler.inverse_transform(d)
    return d


torch.manual_seed(0)
prev_x = test_loader.dataset.tensors[0][:validation_size][-1].to("cuda")
prev_y = test_loader.dataset.tensors[1][:validation_size][-1].to("cuda")



def compute_last_h(trials, prev_x, prev_y):
    errors = []
    h_list = []
    metric = nn.MSELoss()
    reconstruction_list = []
    for i in range(trials):
        # print(prev_x.shape)
        _, reconstructions, hidden_states, _, _, _, _, _ = model(prev_x, prev_y)
        errors.append(metric(torch.stack(reconstructions).view(-1)[-1], prev_y[1:][-1]))
        h_list.append(hidden_states)
        reconstruction_list.append(torch.stack(reconstructions).detach().to("cpu").numpy())
    val, idx = min((val, idx) for (idx, val) in enumerate(errors))
    return h_list[idx][-1], reconstruction_list[idx]

last_val_h, reconstructions = compute_last_h(500, prev_x, prev_y)


pred_size = 50
new_x = test_loader.dataset.tensors[0][validation_size:].view(-1,6).to("cuda")
new_y = test_loader.dataset.tensors[1][validation_size:].view(-1)
new_y = inverse(new_y.view(-1,1),scaler)[:,6]


def make_predictions(model, pred_size, h_start, scaler, new_x):
    predicted_prices = []
    Z_t = torch.zeros(model.Z_size).to("cuda").unsqueeze(0).unsqueeze(0)
    h_t = torch.zeros(model.gru_hidden_size).to("cuda").unsqueeze(0).unsqueeze(0)
    hs = []
    for i in range(pred_size):
        new_Z = model.Z_prior(h_start)
        new_Z = torch.chunk(new_Z, 2, dim=-1)
        Z_std = torch.exp(0.5*new_Z[1])
        new_Z = sample_from_normal(new_Z[0],Z_std)
        # Z_t = torch.cat((Z_t,new_Z.unsqueeze(0).unsqueeze(0)),1)
        # att,draw = model.laten_att(Z_t[1:],h_start)
        Z_t = torch.cat((Z_t,new_Z.unsqueeze(0).unsqueeze(0)),0)
        att,draw = model.laten_att(Z_t[1:],h_start)
        # att,_ = model.adat(None,h_start.unsqueeze(0),Z_t[1:])
        x_prime = torch.cat([att,new_x[i].view(-1).float()])
        # x_prime = torch.cat([new_Z, new_x[i].view(-1).float()])
        h_start,_ = model.run_GRU(x_prime,h_start)
        # h_t = torch.cat((h_t,h_start.unsqueeze(0).unsqueeze(0)),1)
        hs.append(h_start)
    # tem = model.mha(Z_t[:,1:],Z_t[:,1:],h_t[:,1:],None)[0][0]
    for i in range(pred_size):
        _,predicted_price,_ = model.reconstruct(hs[i])
        predicted_price = predicted_price.to("cpu")
        predicted_price = inverse(predicted_price.view(-1,1),scaler)[:,6]
        predicted_prices.append(max(predicted_price,0))
    
    return predicted_prices

def trial(trials, model, hidden_states, pred_size, new_x):
    predictions = []
    upper_90 = []
    lower_90 = []
    upper_95 = []
    lower_95 = []
    mean = []
    for i in range(trials):
        predicted_prices = make_predictions(model, pred_size, hidden_states, scaler, new_x)
        predicted_prices = np.vstack(predicted_prices)
        predictions.append(predicted_prices)
       
    predictions = np.concatenate(predictions, axis=1)
        
    for j in range(pred_size):
        temp = predictions[j]
        upper_90.append(np.percentile(temp,95))
        lower_90.append(np.percentile(temp,5))
        upper_95.append(np.percentile(temp,97.5))
        lower_95.append(np.percentile(temp,2.5))
        mean.append(np.mean(temp))
    print(pred_size,RMSELoss(torch.tensor(mean),new_y[:pred_size]))

    return upper_90, lower_90, upper_95, lower_95, mean


u_90, l_90, u_95, l_95, m = trial(1000, model, last_val_h, pred_size, new_x)

  
############################################################################
offset = 200
plt.rcParams["figure.figsize"] = (15,6)
actual_values = data["pm2.5"].tolist()[:tw*(len(data)//tw)]

end_idx = val_steps+pred_size+train_steps
start_idx = end_idx-pred_size-val_steps
actual_range = actual_values[start_idx:end_idx]


validation_end = len(actual_range) - pred_size + 1
validation_start = validation_end - val_steps
min_val = min(actual_range[validation_start:validation_end])
max_val = max(actual_range[validation_start:validation_end])


plt.plot(actual_range,color="teal", label="actual")
plt.plot([i+val_steps for i in range(len(m))],m, color="deeppink", label="mean prediction")
plt.fill_between([i+val_steps for i in range(len(m))], u_95, l_95,
                 color='deeppink', alpha=0.2, label="95% confidence interval")
plt.fill_between([i+val_steps for i in range(len(m))], u_90, l_90,
                 color='cyan', alpha=0.2, label="90% confidence interval")

plt.xlabel("observation point")
plt.ylabel("pm 2.5")
plt.legend(loc="upper left",  prop={"size":15})
plt.grid()
ticks,labels = plt.xticks()
ticks = np.array(list(ticks)[1:-1]).astype(int)
labels = ticks+1201
plt.xticks(ticks, labels)
plt.savefig("attenz_pm_50.png")
pred_list = [5,10,15,20,25,30,40,50]
for i in pred_list:
  u_90, l_90, u_95, l_95, m = trial(500, model, last_val_h, i, new_x)
#######################################
# Out:
# 	Epoch: 0, Train Loss: 2125.7326, Validation Loss: 23.2941
# 	Epoch: 1, Train Loss: 2026.3428, Validation Loss: 23.0199
# 	Epoch: 2, Train Loss: 1934.7037, Validation Loss: 23.0966
# 	Epoch: 3, Train Loss: 1857.2088, Validation Loss: 22.6398
# 	Epoch: 4, Train Loss: 1794.8235, Validation Loss: 21.8136
# 	Epoch: 5, Train Loss: 1741.6312, Validation Loss: 22.5145
# 	Epoch: 6, Train Loss: 1693.3664, Validation Loss: 22.3692
# 	Epoch: 7, Train Loss: 1655.2020, Validation Loss: 22.2905
# 	Epoch: 8, Train Loss: 1619.5817, Validation Loss: 21.7852
# 	Epoch: 9, Train Loss: 1596.5446, Validation Loss: 21.8853
# 	Epoch: 10, Train Loss: 1563.7798, Validation Loss: 20.5302
# 	Epoch: 11, Train Loss: 1548.9198, Validation Loss: 20.3317
# 	Epoch: 12, Train Loss: 1529.3250, Validation Loss: 21.1084
# 	Epoch: 13, Train Loss: 1524.0388, Validation Loss: 20.4657
# 	Epoch: 14, Train Loss: 1505.6135, Validation Loss: 20.0932
# 	Epoch: 15, Train Loss: 1488.7067, Validation Loss: 19.3830
# 	Epoch: 16, Train Loss: 1472.9729, Validation Loss: 18.5417
# 	Epoch: 17, Train Loss: 1460.0276, Validation Loss: 19.5125
# 	Epoch: 18, Train Loss: 1453.1268, Validation Loss: 16.8585
# 	Epoch: 19, Train Loss: 1435.2295, Validation Loss: 17.5330
# 	Epoch: 20, Train Loss: 1415.5020, Validation Loss: 16.2944
# 	Epoch: 21, Train Loss: 1411.8452, Validation Loss: 17.3707
# 	Epoch: 22, Train Loss: 1389.3348, Validation Loss: 16.3036
# 	Epoch: 23, Train Loss: 1369.0908, Validation Loss: 17.3496
# 	Epoch: 24, Train Loss: 1371.6388, Validation Loss: 15.3697
# 	Epoch: 25, Train Loss: 1365.3471, Validation Loss: 14.4050
# 	Epoch: 26, Train Loss: 1360.5420, Validation Loss: 16.7383
# 	Epoch: 27, Train Loss: 1343.4464, Validation Loss: 15.7204
# 	Epoch: 28, Train Loss: 1328.9325, Validation Loss: 17.8394
# 	Epoch: 29, Train Loss: 1328.7777, Validation Loss: 14.4885
# 	Epoch: 30, Train Loss: 1327.6649, Validation Loss: 15.0492
# 	Epoch: 31, Train Loss: 1328.0026, Validation Loss: 14.0271
# 	Epoch: 32, Train Loss: 1332.2184, Validation Loss: 13.3091
# 	Epoch: 33, Train Loss: 1302.5435, Validation Loss: 13.1650
# 	Epoch: 34, Train Loss: 1314.8217, Validation Loss: 17.6122
# 	Epoch: 35, Train Loss: 1315.5059, Validation Loss: 14.3134
# 	Epoch: 36, Train Loss: 1296.6743, Validation Loss: 15.4555
# 	Epoch: 37, Train Loss: 1321.2326, Validation Loss: 17.4671
# 	Epoch: 38, Train Loss: 1301.8735, Validation Loss: 15.0635
# 	Epoch: 39, Train Loss: 1300.2815, Validation Loss: 15.4273
# 	Epoch: 40, Train Loss: 1314.0013, Validation Loss: 11.7660
# 	Epoch: 41, Train Loss: 1286.1479, Validation Loss: 14.9713
# 	Epoch: 42, Train Loss: 1282.1089, Validation Loss: 14.7399
# 	Epoch: 43, Train Loss: 1259.4700, Validation Loss: 14.3099
# 	Epoch: 44, Train Loss: 1278.9304, Validation Loss: 12.6453
# 	Epoch: 45, Train Loss: 1278.5031, Validation Loss: 13.5893
# 	Epoch: 46, Train Loss: 1284.0060, Validation Loss: 12.1026
# 	Epoch: 47, Train Loss: 1287.5845, Validation Loss: 13.1720
# 	Epoch: 48, Train Loss: 1309.2611, Validation Loss: 14.3255
# 	Epoch: 49, Train Loss: 1289.8255, Validation Loss: 15.1241
# 	Epoch: 50, Train Loss: 1301.4662, Validation Loss: 13.4663
# 	Epoch: 51, Train Loss: 1257.0585, Validation Loss: 15.3873
# 	Epoch: 52, Train Loss: 1261.0032, Validation Loss: 12.4791
# 	Epoch: 53, Train Loss: 1275.1783, Validation Loss: 15.7211
# 	Epoch: 54, Train Loss: 1284.5988, Validation Loss: 14.3335
# 	Epoch: 55, Train Loss: 1273.2935, Validation Loss: 15.0923
# 	Epoch: 56, Train Loss: 1269.4407, Validation Loss: 13.5633
# 	Epoch: 57, Train Loss: 1266.4202, Validation Loss: 15.7754
# 	Epoch: 58, Train Loss: 1275.0572, Validation Loss: 14.2531
# 	Epoch: 59, Train Loss: 1280.7253, Validation Loss: 13.7970
# 	Epoch: 60, Train Loss: 1293.7876, Validation Loss: 14.4912
# 	Epoch: 61, Train Loss: 1280.2117, Validation Loss: 11.5918
# 	Epoch: 62, Train Loss: 1274.1648, Validation Loss: 14.6286
# 	Epoch: 63, Train Loss: 1267.0663, Validation Loss: 13.9978
# 	Epoch: 64, Train Loss: 1281.6912, Validation Loss: 14.2993
# 	Epoch: 65, Train Loss: 1266.6054, Validation Loss: 14.9804
# 	Epoch: 66, Train Loss: 1277.6373, Validation Loss: 12.4398
# 	Epoch: 67, Train Loss: 1246.9974, Validation Loss: 14.4854
# 	Epoch: 68, Train Loss: 1259.4793, Validation Loss: 12.9520
# 	Epoch: 69, Train Loss: 1273.3051, Validation Loss: 13.7986
# 	Epoch: 70, Train Loss: 1261.8006, Validation Loss: 13.3324
# 	Epoch: 71, Train Loss: 1255.2611, Validation Loss: 14.4330
# 	Epoch: 72, Train Loss: 1259.8811, Validation Loss: 11.5941
# 	Epoch: 73, Train Loss: 1274.4071, Validation Loss: 13.1187
# 	Epoch: 74, Train Loss: 1274.5341, Validation Loss: 13.9446
# 	Epoch: 75, Train Loss: 1244.4662, Validation Loss: 14.9519
# 	Epoch: 76, Train Loss: 1257.5269, Validation Loss: 12.8400
# 	Epoch: 77, Train Loss: 1255.3010, Validation Loss: 12.7512
# 	Epoch: 78, Train Loss: 1286.9912, Validation Loss: 14.3984
# 	Epoch: 79, Train Loss: 1268.8702, Validation Loss: 12.6308
# 	Epoch: 80, Train Loss: 1246.8946, Validation Loss: 13.9525
# 	Epoch: 81, Train Loss: 1261.0309, Validation Loss: 14.7287
# 	Epoch: 82, Train Loss: 1266.2769, Validation Loss: 13.8346
# 	Epoch: 83, Train Loss: 1267.1421, Validation Loss: 13.2062
# 	Epoch: 84, Train Loss: 1279.1954, Validation Loss: 13.0615
# 	Epoch: 85, Train Loss: 1273.8648, Validation Loss: 15.7799
# 	Epoch: 86, Train Loss: 1256.5672, Validation Loss: 13.3329
# 	Epoch: 87, Train Loss: 1253.2104, Validation Loss: 14.5843
# 	Epoch: 88, Train Loss: 1271.5728, Validation Loss: 16.0573
# 	Epoch: 89, Train Loss: 1253.6600, Validation Loss: 10.9468
# 	Epoch: 90, Train Loss: 1251.0285, Validation Loss: 12.6119
# 	Epoch: 91, Train Loss: 1259.0984, Validation Loss: 12.4677
# 	Epoch: 92, Train Loss: 1260.6268, Validation Loss: 14.6999
# 	Epoch: 93, Train Loss: 1264.1863, Validation Loss: 12.6012
# 	Epoch: 94, Train Loss: 1247.5511, Validation Loss: 12.9544
# 	Epoch: 95, Train Loss: 1258.7374, Validation Loss: 14.0996
# 	Epoch: 96, Train Loss: 1250.4313, Validation Loss: 13.8588
# 	Epoch: 97, Train Loss: 1244.4567, Validation Loss: 13.6236
# 	Epoch: 98, Train Loss: 1258.5528, Validation Loss: 14.5906
# 	Epoch: 99, Train Loss: 1248.9504, Validation Loss: 13.8542
# 	Epoch: 100, Train Loss: 1264.9689, Validation Loss: 13.1664
# 	Epoch: 101, Train Loss: 1255.0495, Validation Loss: 13.0919
# 	Epoch: 102, Train Loss: 1245.8456, Validation Loss: 13.7534
# 	Epoch: 103, Train Loss: 1258.3679, Validation Loss: 12.7559
# 	Epoch: 104, Train Loss: 1263.4075, Validation Loss: 14.4294
# 	Epoch: 105, Train Loss: 1259.2324, Validation Loss: 11.5866
# 	Epoch: 106, Train Loss: 1248.2973, Validation Loss: 13.0182
# 	Epoch: 107, Train Loss: 1262.6328, Validation Loss: 12.9224
# 	Epoch: 108, Train Loss: 1236.8738, Validation Loss: 13.3110
# 	Epoch: 109, Train Loss: 1249.5893, Validation Loss: 13.9674
# 	Epoch: 110, Train Loss: 1273.0051, Validation Loss: 12.4144
# 	Epoch: 111, Train Loss: 1255.4948, Validation Loss: 13.2891
# 	Epoch: 112, Train Loss: 1242.5806, Validation Loss: 12.3844
# 	Epoch: 113, Train Loss: 1262.5324, Validation Loss: 12.0922
# 	Epoch: 114, Train Loss: 1231.1677, Validation Loss: 13.2923
# 	Epoch: 115, Train Loss: 1256.4667, Validation Loss: 12.8276
# 	Epoch: 116, Train Loss: 1234.8663, Validation Loss: 11.9518
# 	Epoch: 117, Train Loss: 1268.2259, Validation Loss: 13.1378
# 	Epoch: 118, Train Loss: 1266.2726, Validation Loss: 13.4932
# 	Epoch: 119, Train Loss: 1243.2623, Validation Loss: 13.7035
# 	Epoch: 120, Train Loss: 1246.9418, Validation Loss: 13.0491
# 	Epoch: 121, Train Loss: 1266.6204, Validation Loss: 14.9671
# 	Epoch: 122, Train Loss: 1244.7062, Validation Loss: 12.9727
# 	Epoch: 123, Train Loss: 1247.4871, Validation Loss: 10.7212
# 	Epoch: 124, Train Loss: 1241.3867, Validation Loss: 11.4473
# 	Epoch: 125, Train Loss: 1249.2193, Validation Loss: 12.1215
# 	Epoch: 126, Train Loss: 1244.7699, Validation Loss: 10.6527
# 	Epoch: 127, Train Loss: 1240.7090, Validation Loss: 12.3806
# 	Epoch: 128, Train Loss: 1249.9357, Validation Loss: 13.4964
# 	Epoch: 129, Train Loss: 1235.2053, Validation Loss: 12.0923
# 	Epoch: 130, Train Loss: 1238.3436, Validation Loss: 10.2334
# 	Epoch: 131, Train Loss: 1255.2800, Validation Loss: 13.2003
# 	Epoch: 132, Train Loss: 1256.2050, Validation Loss: 12.4695
# 	Epoch: 133, Train Loss: 1239.3564, Validation Loss: 14.3373
# 	Epoch: 134, Train Loss: 1247.2361, Validation Loss: 11.8163
# 	Epoch: 135, Train Loss: 1234.4331, Validation Loss: 12.7708
# 	Epoch: 136, Train Loss: 1269.9261, Validation Loss: 13.1646
# 	Epoch: 137, Train Loss: 1240.1965, Validation Loss: 13.3342
# 	Epoch: 138, Train Loss: 1263.8993, Validation Loss: 11.8753
# 	Epoch: 139, Train Loss: 1258.2260, Validation Loss: 11.2402
# 	Epoch: 140, Train Loss: 1237.3144, Validation Loss: 10.9101
# 	Epoch: 141, Train Loss: 1220.1338, Validation Loss: 12.9734
# 	Epoch: 142, Train Loss: 1249.9939, Validation Loss: 12.1738
# 	Epoch: 143, Train Loss: 1251.0181, Validation Loss: 9.8997
# 	Epoch: 144, Train Loss: 1269.6151, Validation Loss: 10.8889
# 	Epoch: 145, Train Loss: 1222.5671, Validation Loss: 11.5203
# 	Epoch: 146, Train Loss: 1269.5055, Validation Loss: 13.7032
# 	Epoch: 147, Train Loss: 1238.6905, Validation Loss: 9.8694
# 	Epoch: 148, Train Loss: 1252.9648, Validation Loss: 13.9571
# 	Epoch: 149, Train Loss: 1258.5248, Validation Loss: 11.0299
# 	Epoch: 150, Train Loss: 1230.8354, Validation Loss: 10.2126
# 	Epoch: 151, Train Loss: 1247.4540, Validation Loss: 11.8531
# 	Epoch: 152, Train Loss: 1245.3248, Validation Loss: 12.0294
# 	Epoch: 153, Train Loss: 1233.9529, Validation Loss: 11.7860
# 	Epoch: 154, Train Loss: 1238.9498, Validation Loss: 10.7163
# 	Epoch: 155, Train Loss: 1226.0674, Validation Loss: 12.4253
# 	Epoch: 156, Train Loss: 1235.9888, Validation Loss: 10.4327
# 	Epoch: 157, Train Loss: 1233.5618, Validation Loss: 12.5713
# 	Epoch: 158, Train Loss: 1255.2592, Validation Loss: 10.2497
# 	Epoch: 159, Train Loss: 1246.6578, Validation Loss: 11.0839
# 	Epoch: 160, Train Loss: 1230.0469, Validation Loss: 11.4401
# 	Epoch: 161, Train Loss: 1232.8020, Validation Loss: 13.7339
# 	Epoch: 162, Train Loss: 1249.3152, Validation Loss: 10.1228
# 	Epoch: 163, Train Loss: 1251.4271, Validation Loss: 13.2093
# 	Epoch: 164, Train Loss: 1221.9534, Validation Loss: 10.4465
# 	Epoch: 165, Train Loss: 1249.0101, Validation Loss: 11.9710
# 	Epoch: 166, Train Loss: 1257.2545, Validation Loss: 13.6459
# 	Epoch: 167, Train Loss: 1213.3261, Validation Loss: 10.2424
# 	Epoch: 168, Train Loss: 1209.0858, Validation Loss: 12.6317
# 	Epoch: 169, Train Loss: 1201.6219, Validation Loss: 11.0004
# 	Epoch: 170, Train Loss: 1231.8073, Validation Loss: 9.4571
# 	Epoch: 171, Train Loss: 1220.1954, Validation Loss: 12.3541
# 	Epoch: 172, Train Loss: 1252.3470, Validation Loss: 10.2717
# 	Epoch: 173, Train Loss: 1245.0009, Validation Loss: 9.6401
# 	Epoch: 174, Train Loss: 1250.9501, Validation Loss: 10.5740
# 	Epoch: 175, Train Loss: 1240.6922, Validation Loss: 11.0314
# 	Epoch: 176, Train Loss: 1250.2535, Validation Loss: 11.9656
# 	Epoch: 177, Train Loss: 1221.6379, Validation Loss: 11.6227
# 	Epoch: 178, Train Loss: 1201.7940, Validation Loss: 12.3246
# 	Epoch: 179, Train Loss: 1243.4414, Validation Loss: 9.0869
# 	Epoch: 180, Train Loss: 1247.0901, Validation Loss: 9.7108
# 	Epoch: 181, Train Loss: 1244.5654, Validation Loss: 12.2851
# 	Epoch: 182, Train Loss: 1228.0443, Validation Loss: 10.4014
# 	Epoch: 183, Train Loss: 1254.1907, Validation Loss: 9.5836
# 	Epoch: 184, Train Loss: 1228.4187, Validation Loss: 10.9851
# 	Epoch: 185, Train Loss: 1214.6995, Validation Loss: 9.3062
# 	Epoch: 186, Train Loss: 1203.2895, Validation Loss: 9.5142
# 	Epoch: 187, Train Loss: 1234.0807, Validation Loss: 10.5994
# 	Epoch: 188, Train Loss: 1226.8942, Validation Loss: 9.8052
# 	Epoch: 189, Train Loss: 1232.4064, Validation Loss: 10.0772
# 	Epoch: 190, Train Loss: 1211.9286, Validation Loss: 12.2564
# 	Epoch: 191, Train Loss: 1228.9559, Validation Loss: 10.0241
# 	Epoch: 192, Train Loss: 1242.1419, Validation Loss: 8.4052
# 	Epoch: 193, Train Loss: 1224.9543, Validation Loss: 9.3910
# 	Epoch: 194, Train Loss: 1202.2701, Validation Loss: 9.5794
# 	Epoch: 195, Train Loss: 1222.4162, Validation Loss: 9.8837
# 	Epoch: 196, Train Loss: 1229.0870, Validation Loss: 9.8565
# 	Epoch: 197, Train Loss: 1230.4830, Validation Loss: 10.8668
# 	Epoch: 198, Train Loss: 1200.8312, Validation Loss: 10.4937
# 	Epoch: 199, Train Loss: 1251.6705, Validation Loss: 11.4598
# 	Epoch: 200, Train Loss: 1220.6601, Validation Loss: 9.3678
# 	Epoch: 201, Train Loss: 1226.9490, Validation Loss: 6.2216
# 	Epoch: 202, Train Loss: 1215.8206, Validation Loss: 12.2599
# 	Epoch: 203, Train Loss: 1236.6141, Validation Loss: 11.8175
# 	Epoch: 204, Train Loss: 1240.6836, Validation Loss: 9.3302
# 	Epoch: 205, Train Loss: 1209.0436, Validation Loss: 10.2654
# 	Epoch: 206, Train Loss: 1228.1133, Validation Loss: 10.6521
# 	Epoch: 207, Train Loss: 1243.9028, Validation Loss: 10.9285
# 	Epoch: 208, Train Loss: 1216.5643, Validation Loss: 8.7132
# 	Epoch: 209, Train Loss: 1246.0410, Validation Loss: 10.8279
# 	Epoch: 210, Train Loss: 1246.0794, Validation Loss: 13.2264
# 	Epoch: 211, Train Loss: 1238.1739, Validation Loss: 10.2068
# 	Epoch: 212, Train Loss: 1232.9837, Validation Loss: 9.5189
# 	Epoch: 213, Train Loss: 1257.9193, Validation Loss: 11.6127
# 	Epoch: 214, Train Loss: 1216.5620, Validation Loss: 11.6860
# 	Epoch: 215, Train Loss: 1219.0963, Validation Loss: 9.3970
# 	Epoch: 216, Train Loss: 1220.7453, Validation Loss: 10.6124
# 	Epoch: 217, Train Loss: 1230.1330, Validation Loss: 9.3138
# 	Epoch: 218, Train Loss: 1229.6073, Validation Loss: 11.4675
# 	Epoch: 219, Train Loss: 1236.3427, Validation Loss: 10.1299
# 	Epoch: 220, Train Loss: 1224.1864, Validation Loss: 8.7858
# 	Epoch: 221, Train Loss: 1227.3685, Validation Loss: 8.0463
# 	Epoch: 222, Train Loss: 1212.1026, Validation Loss: 9.8147
# 	Epoch: 223, Train Loss: 1195.9469, Validation Loss: 11.2004
# 	Epoch: 224, Train Loss: 1225.8012, Validation Loss: 8.7802
# 	Epoch: 225, Train Loss: 1238.5211, Validation Loss: 10.1891
# 	Epoch: 226, Train Loss: 1229.9504, Validation Loss: 9.3044
# 	Epoch: 227, Train Loss: 1221.4417, Validation Loss: 9.9801
# 	Epoch: 228, Train Loss: 1188.9121, Validation Loss: 8.5322
# 	Epoch: 229, Train Loss: 1231.3268, Validation Loss: 6.6702
# 	Epoch: 230, Train Loss: 1231.3133, Validation Loss: 8.0446
# 	Epoch: 231, Train Loss: 1185.9288, Validation Loss: 10.8524
# 	Epoch: 232, Train Loss: 1197.6736, Validation Loss: 7.2336
# 	Epoch: 233, Train Loss: 1215.1753, Validation Loss: 11.5568
# 	Epoch: 234, Train Loss: 1220.0006, Validation Loss: 8.8969
# 	Epoch: 235, Train Loss: 1224.6990, Validation Loss: 10.3595
# 	Epoch: 236, Train Loss: 1217.2113, Validation Loss: 9.3767
# 	Epoch: 237, Train Loss: 1207.4163, Validation Loss: 8.6468
# 	Epoch: 238, Train Loss: 1225.3290, Validation Loss: 9.5177
# 	Epoch: 239, Train Loss: 1218.8980, Validation Loss: 9.8150
# 	Epoch: 240, Train Loss: 1218.7466, Validation Loss: 8.7183
# 	Epoch: 241, Train Loss: 1230.6177, Validation Loss: 9.3796
# 	Epoch: 242, Train Loss: 1239.1701, Validation Loss: 8.3204
# 	Epoch: 243, Train Loss: 1206.1808, Validation Loss: 6.7589
# 	Epoch: 244, Train Loss: 1206.2684, Validation Loss: 7.4292
# 	Epoch: 245, Train Loss: 1214.7836, Validation Loss: 10.6439
# 	Epoch: 246, Train Loss: 1194.5387, Validation Loss: 11.7710
# 	Epoch: 247, Train Loss: 1238.1028, Validation Loss: 6.6261
# 	Epoch: 248, Train Loss: 1218.1249, Validation Loss: 9.2775
# 	Epoch: 249, Train Loss: 1240.9566, Validation Loss: 7.7712
# 	Epoch: 250, Train Loss: 1215.2925, Validation Loss: 12.8309
# 	Epoch: 251, Train Loss: 1203.0974, Validation Loss: 10.0969
# 	Epoch: 252, Train Loss: 1183.4993, Validation Loss: 9.5529
# 	Epoch: 253, Train Loss: 1199.6277, Validation Loss: 11.7952
# 	Epoch: 254, Train Loss: 1198.3499, Validation Loss: 8.9522
# 	Epoch: 255, Train Loss: 1194.6874, Validation Loss: 7.0116
# 	Epoch: 256, Train Loss: 1197.0203, Validation Loss: 9.7632
# 	Epoch: 257, Train Loss: 1213.1087, Validation Loss: 9.5286
# 	Epoch: 258, Train Loss: 1219.0884, Validation Loss: 10.1531
# 	Epoch: 259, Train Loss: 1191.8674, Validation Loss: 8.8507
# 	Epoch: 260, Train Loss: 1222.3401, Validation Loss: 7.5412
# 	Epoch: 261, Train Loss: 1233.6144, Validation Loss: 7.2436
# 	Epoch: 262, Train Loss: 1198.2196, Validation Loss: 7.7236
# 	Epoch: 263, Train Loss: 1216.8479, Validation Loss: 9.7950
# 	Epoch: 264, Train Loss: 1187.5277, Validation Loss: 8.3984
# 	Epoch: 265, Train Loss: 1204.9673, Validation Loss: 12.1336
# 	Epoch: 266, Train Loss: 1218.5336, Validation Loss: 10.1208
# 	Epoch: 267, Train Loss: 1205.5357, Validation Loss: 10.6126
# 	Epoch: 268, Train Loss: 1228.3346, Validation Loss: 8.0303
# 	Epoch: 269, Train Loss: 1204.8999, Validation Loss: 8.7234
# 	Epoch: 270, Train Loss: 1204.2050, Validation Loss: 12.1710
# 	Epoch: 271, Train Loss: 1194.2929, Validation Loss: 9.5463
# 	Epoch: 272, Train Loss: 1212.5679, Validation Loss: 10.6182
# 	Epoch: 273, Train Loss: 1222.0989, Validation Loss: 8.0948
# 	Epoch: 274, Train Loss: 1198.2768, Validation Loss: 11.8203
# 	Epoch: 275, Train Loss: 1210.9185, Validation Loss: 6.6963
# 	Epoch: 276, Train Loss: 1187.2464, Validation Loss: 8.2380
# 	Epoch: 277, Train Loss: 1191.1307, Validation Loss: 8.2245
# 	Epoch: 278, Train Loss: 1197.2587, Validation Loss: 8.6334
# 	Epoch: 279, Train Loss: 1203.7519, Validation Loss: 7.3509
# 	Epoch: 280, Train Loss: 1188.2938, Validation Loss: 8.0674
# 	Epoch: 281, Train Loss: 1225.0218, Validation Loss: 9.4667
# 	Epoch: 282, Train Loss: 1223.3107, Validation Loss: 9.2819
# 	Epoch: 283, Train Loss: 1199.8031, Validation Loss: 8.8924
# 	Epoch: 284, Train Loss: 1221.8019, Validation Loss: 8.9080
# 	Epoch: 285, Train Loss: 1219.5413, Validation Loss: 6.3930
# 	Epoch: 286, Train Loss: 1216.9008, Validation Loss: 10.9260
# 	Epoch: 287, Train Loss: 1198.0198, Validation Loss: 7.7132
# 	Epoch: 288, Train Loss: 1229.9861, Validation Loss: 7.2152
# 	Epoch: 289, Train Loss: 1214.7420, Validation Loss: 11.1804
# 	Epoch: 290, Train Loss: 1177.4316, Validation Loss: 8.5210
# 	Epoch: 291, Train Loss: 1194.5433, Validation Loss: 7.1909
# 	Epoch: 292, Train Loss: 1222.2917, Validation Loss: 11.1257
# 	Epoch: 293, Train Loss: 1228.3681, Validation Loss: 9.5200
# 	Epoch: 294, Train Loss: 1198.5214, Validation Loss: 8.4379
# 	Epoch: 295, Train Loss: 1197.7192, Validation Loss: 10.0582
# 	Epoch: 296, Train Loss: 1194.5798, Validation Loss: 8.7131
# 	Epoch: 297, Train Loss: 1183.7062, Validation Loss: 9.8963
# 	Epoch: 298, Train Loss: 1194.6957, Validation Loss: 8.7996
# 	Epoch: 299, Train Loss: 1222.6944, Validation Loss: 8.5573
# 50 tensor(0.6993, dtype=torch.float64)
# 5 tensor(0.3062, dtype=torch.float64)
# 10 tensor(0.3547, dtype=torch.float64)
# 15 tensor(0.5090, dtype=torch.float64)
# 20 tensor(0.5416, dtype=torch.float64)
# 25 tensor(0.6373, dtype=torch.float64)
# 30 tensor(0.6365, dtype=torch.float64)
# 40 tensor(0.6339, dtype=torch.float64)
# 50 tensor(0.7011, dtype=torch.float64)
